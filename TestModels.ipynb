# %% [markdown]
# ## Test models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip
# !unzip 'caption_datasets.zip'
# !rm -r 'caption_datasets.zip'
# Out:
# --2023-07-27 00:49:39--  http://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip
# Resolving cs.stanford.edu (cs.stanford.edu)... 171.64.64.64
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip [following]
# --2023-07-27 00:49:40--  https://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36745453 (35M) [application/zip]
# Saving to: ‘caption_datasets.zip’
#
# caption_datasets.zi 100%[===================>]  35.04M  11.4MB/s    in 3.1s
#
# 2023-07-27 00:49:43 (11.4 MB/s) - ‘caption_datasets.zip’ saved [36745453/36745453]
#
# Archive:  caption_datasets.zip
#   inflating: dataset_coco.json
#   inflating: dataset_flickr30k.json
# ...

# %%
# %matplotlib inline
# !python "/content/drive/MyDrive/image_captioning/testmodel.py" -h
# Out:
# usage: testmodel.py
#        [-h]
#        [-pm PATH_MODEL]
#        [-t TYPE]
#        [-pi PATH]
#        [-cp PATH_CAPTION]
#        [-b BEAM]
#
# Test models
#
# options:
#   -h, --help
#     show this
#     help
#     message and
#     exit
#   -pm PATH_MODEL, --path_model PATH_MODEL
#     path of
#     models
#   -t TYPE, --type TYPE
#     type of
#     model
#     (attention
#     or noattent
#     ion)
#   -pi PATH, --path PATH
#     path of
#     image
#   -cp PATH_CAPTION, --path_caption PATH_CAPTION
#     path of
#     caption
#     dataset
#   -b BEAM, --beam BEAM
#     Beam size

# %%
# %run "/content/drive/MyDrive/image_captioning/testmodel.py" -pm "/content/drive/MyDrive/image_captioning/image_captioning_best_30k_300d.pth" -t "attention" -cp "./dataset_flickr30k.json" -pi "/content/1007129816.jpg" -b 1
# Out:
# a man with a colorful hat and a blue shirt

# %%
# %run "/content/drive/MyDrive/image_captioning/testmodel.py" -pm "/content/drive/MyDrive/image_captioning/image_captioning_best_30k_embedding_fasttext.pth" -t "attention" -cp "./dataset_flickr30k.json" -pi "/content/1007129816.jpg" -b 1
# Out:
# a man wearing a hat is holding a large trophy

# %%
# %run "/content/drive/MyDrive/image_captioning/testmodel.py" -pm "/content/drive/MyDrive/image_captioning/image_captioning_best_30k_embedding.pth" -t "attention" -cp "./dataset_flickr30k.json" -pi "/content/1007129816.jpg" -b 1
# Out:
# a man with a beard and a clown is smiling
