# %% [markdown]
# ## Evaluate models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip
# !unzip 'caption_datasets.zip'
# !rm -r 'caption_datasets.zip'
# Out:
# --2023-07-28 16:06:02--  http://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip
# Resolving cs.stanford.edu (cs.stanford.edu)... 171.64.64.64
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip [following]
# --2023-07-28 16:06:03--  https://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36745453 (35M) [application/zip]
# Saving to: ‘caption_datasets.zip’
#
# caption_datasets.zi 100%[===================>]  35.04M  11.1MB/s    in 3.2s
#
# 2023-07-28 16:06:07 (11.1 MB/s) - ‘caption_datasets.zip’ saved [36745453/36745453]
#
# Archive:  caption_datasets.zip
#   inflating: dataset_coco.json
#   inflating: dataset_flickr30k.json
# ...

# %%
# !pip install pycocoevalcap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 8.7 MB/s eta 0:00:00
# ...

# %%
# !python "/content/drive/MyDrive/image_captioning/evaluate.py" -h
# Out:
# usage: evaluate.py
#        [-h]
#        [-p PATH]
#        [-tp TRUE_PATH]
#        [-sp SPLIT]
#
# Evaluate
# generated
# captions
#
# options:
#   -h, --help
#     show this
#     help
#     message and
#     exit
#   -p PATH, --path PATH
#     path of
#     generated
#     captions
#     need to
#     evaluate
#   -tp TRUE_PATH, --true_path TRUE_PATH
#     path of
#     true
#     captions
#   -sp SPLIT, --split SPLIT
#     type of
#     split

# %%
# !python "/content/drive/MyDrive/image_captioning/evaluate.py" --path "/content/drive/MyDrive/image_captioning/generated_captions/generated_captions_8k_attention_300d.json" --true_path "./dataset_flickr8k.json"
# Out:
# tokenization...
# PTBTokenizer tokenized 59662 tokens at 164794.48 tokens per second.
# PTBTokenizer tokenized 10529 tokens at 60181.42 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 9530, 'reflen': 9609, 'guess': [9530, 8530, 7530, 6530], 'correct': [6095, 2804, 1160, 448]}
# ratio: 0.9917785409510883
# Bleu_1: 0.634
# Bleu_2: 0.455
# Bleu_3: 0.316
# Bleu_4: 0.215
# computing METEOR score...
# METEOR: 0.203
# computing Rouge score...
# ROUGE_L: 0.466
# computing CIDEr score...
# CIDEr: 0.513
# {'Bleu_1': 0.6342795022015995, 'Bleu_2': 0.4547312084353634, 'Bleu_3': 0.31612399925105955, 'Bleu_4': 0.21531995265835094, 'METEOR': 0.2029577553730984, 'ROUGE_L': 0.4663048856801107, 'CIDEr': 0.5131115938174448}

# %%
# !python "/content/drive/MyDrive/image_captioning/evaluate.py" --path "/content/drive/MyDrive/image_captioning/generated_captions_8k_embedding.json" --true_path "./dataset_flickr8k.json"
# Out:
# tokenization...
# PTBTokenizer tokenized 59662 tokens at 167337.19 tokens per second.
# PTBTokenizer tokenized 10833 tokens at 29386.51 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 9834, 'reflen': 9795, 'guess': [9834, 8834, 7834, 6834], 'correct': [6322, 2914, 1287, 532]}
# ratio: 1.0039816232770797
# Bleu_1: 0.643
# Bleu_2: 0.460
# Bleu_3: 0.327
# Bleu_4: 0.228
# computing METEOR score...
# METEOR: 0.209
# computing Rouge score...
# ROUGE_L: 0.472
# computing CIDEr score...
# CIDEr: 0.543
# {'Bleu_1': 0.6428716697172419, 'Bleu_2': 0.46049850014834576, 'Bleu_3': 0.3266007215810044, 'Bleu_4': 0.2282033520347521, 'METEOR': 0.20939562004454826, 'ROUGE_L': 0.4721528665110043, 'CIDEr': 0.5425482330997012}

# %% [markdown]
# ## Flickr30k attention

# %%
# !python "/content/drive/MyDrive/image_captioning/evaluate.py" --path "/content/drive/MyDrive/image_captioning/generated_captions_30k_attention.json" --true_path "./dataset_flickr30k.json" --split "test"
# Out:
# tokenization...
# PTBTokenizer tokenized 67689 tokens at 201118.52 tokens per second.
# PTBTokenizer tokenized 10735 tokens at 33909.51 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 9736, 'reflen': 9972, 'guess': [9736, 8736, 7736, 6736], 'correct': [6539, 3066, 1370, 597]}
# ratio: 0.9763337344563802
# Bleu_1: 0.656
# Bleu_2: 0.474
# Bleu_3: 0.339
# Bleu_4: 0.241
# computing METEOR score...
# METEOR: 0.195
# computing Rouge score...
# ROUGE_L: 0.452
# computing CIDEr score...
# CIDEr: 0.482
# {'Bleu_1': 0.6555464991532949, 'Bleu_2': 0.4738794535225035, 'Bleu_3': 0.3385874563534676, 'Bleu_4': 0.2407212302678552, 'METEOR': 0.19511563912999416, 'ROUGE_L': 0.4517770373172947, 'CIDEr': 0.4821084564239063}

# %% [markdown]
# ## Flickr30k attention GLoVE

# %%
# !python "/content/drive/MyDrive/image_captioning/evaluate.py" --path "/content/drive/MyDrive/image_captioning/generated_captions_30k_embedding.json" --true_path "./dataset_flickr30k.json" --split "test"
# Out:
# tokenization...
# PTBTokenizer tokenized 67689 tokens at 108281.27 tokens per second.
# PTBTokenizer tokenized 10901 tokens at 28568.60 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 9902, 'reflen': 10112, 'guess': [9902, 8902, 7902, 6902], 'correct': [6715, 3172, 1450, 636]}
# ratio: 0.979232594936612
# Bleu_1: 0.664
# Bleu_2: 0.481
# Bleu_3: 0.347
# Bleu_4: 0.248
# computing METEOR score...
# METEOR: 0.198
# computing Rouge score...
# ROUGE_L: 0.463
# computing CIDEr score...
# CIDEr: 0.492
# {'Bleu_1': 0.6639152562601247, 'Bleu_2': 0.4812534937369269, 'Bleu_3': 0.34651558607208466, 'Bleu_4': 0.24751983612736006, 'METEOR': 0.19811013476976072, 'ROUGE_L': 0.4626869000799868, 'CIDEr': 0.4923484399490584}

# %% [markdown]
# ## Flickr30k attention FastText

# %%
# !python "/content/drive/MyDrive/image_captioning/evaluate.py" --path "/content/drive/MyDrive/image_captioning/generated_captions_30k_embedding_fasttext.json" --true_path "./dataset_flickr30k.json" --split "test"
# Out:
# tokenization...
# PTBTokenizer tokenized 67689 tokens at 100758.10 tokens per second.
# PTBTokenizer tokenized 11278 tokens at 30675.44 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 10279, 'reflen': 10338, 'guess': [10279, 9279, 8279, 7279], 'correct': [6843, 3212, 1416, 640]}
# ratio: 0.9942928999805577
# Bleu_1: 0.662
# Bleu_2: 0.477
# Bleu_3: 0.338
# Bleu_4: 0.241
# computing METEOR score...
# METEOR: 0.195
# computing Rouge score...
# ROUGE_L: 0.455
# computing CIDEr score...
# CIDEr: 0.480
# {'Bleu_1': 0.6619160094589032, 'Bleu_2': 0.4773008736191097, 'Bleu_3': 0.33837038606520703, 'Bleu_4': 0.24123933723915675, 'METEOR': 0.1949980486646538, 'ROUGE_L': 0.45477216911356505, 'CIDEr': 0.4800633342964604}
