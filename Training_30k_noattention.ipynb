# %% [markdown]
# Refences: https://colab.research.google.com/github/jaygala24/pytorch-implementations/blob/master/Show%2C%20Attend%20and%20Tell.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1H3ybsP8o7NB75gVnQY2egwzALhsDrMmY/view?usp=view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1H3ybsP8o7NB75gVnQY2egwzALhsDrMmY
# To: /content/flickr30k-images.zip
# 100% 4.38G/4.38G [01:13<00:00, 59.6MB/s]

# %%
#%%capture
# !unzip 'flickr30k-images.zip'
# !rm -r 'flickr30k-images.zip'

# !wget http://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip
# !unzip 'caption_datasets.zip'
# !rm -r 'caption_datasets.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: flickr30k-images/536537638.jpg
#   inflating: flickr30k-images/5366770416.jpg
#   inflating: flickr30k-images/536718060.jpg
#   inflating: flickr30k-images/536721406.jpg
#   inflating: flickr30k-images/5367322642.jpg
#   inflating: flickr30k-images/536739751.jpg
#   inflating: flickr30k-images/536828916.jpg
#   inflating: flickr30k-images/536904709.jpg
#   inflating: flickr30k-images/5369771639.jpg
#   inflating: flickr30k-images/5370581509.jpg
#   inflating: flickr30k-images/537069478.jpg
#   inflating: flickr30k-images/5371109894.jpg
#   inflating: flickr30k-images/5371186400.jpg
#   inflating: flickr30k-images/5371247136.jpg
#   inflating: flickr30k-images/5371507831.jpg
#   inflating: flickr30k-images/5371586024.jpg
#   inflating: flickr30k-images/537222436.jpg
#   inflating: flickr30k-images/537225246.jpg
#   inflating: flickr30k-images/537230454.jpg
#   inflating: flickr30k-images/537359971.jpg
#   inflating: flickr30k-images/5373606679.jpg
#   inflating: flickr30k-images/5373649841.jpg
#   inflating: flickr30k-images/537390477.jpg
#   inflating: flickr30k-images/5374764034.jpg
#   inflating: flickr30k-images/537479916.jpg
#   inflating: flickr30k-images/5375199269.jpg
#   inflating: flickr30k-images/5375305047.jpg
#   inflating: flickr30k-images/537532165.jpg
#   inflating: flickr30k-images/537559285.jpg
#   inflating: flickr30k-images/537579448.jpg
#   inflating: flickr30k-images/537586194.jpg
#   inflating: flickr30k-images/537628742.jpg
#   inflating: flickr30k-images/5377361.jpg
#   inflating: flickr30k-images/537758332.jpg
#   inflating: flickr30k-images/537875659.jpg
#   inflating: flickr30k-images/5379229830.jpg
#   inflating: flickr30k-images/537960889.jpg
#   inflating: flickr30k-images/537968424.jpg
#   inflating: flickr30k-images/5380411758.jpg
#   inflating: flickr30k-images/5380554509.jpg
#   inflating: flickr30k-images/5381043783.jpg
#   inflating: flickr30k-images/5381043991.jpg
#   inflating: flickr30k-images/5381102989.jpg
#   inflating: flickr30k-images/5381104643.jpg
#   inflating: flickr30k-images/5381185036.jpg
#   inflating: flickr30k-images/5381657104.jpg
#   inflating: flickr30k-images/5381663472.jpg
#   inflating: flickr30k-images/5381684062.jpg
#   inflating: flickr30k-images/538271607.jpg
#   inflating: flickr30k-images/538345634.jpg
#   inflating: flickr30k-images/5384132543.jpg
#   inflating: flickr30k-images/5384744603.jpg
#   inflating: flickr30k-images/5385069995.jpg
#   inflating: flickr30k-images/5385135432.jpg
#   inflating: flickr30k-images/5386097747.jpg
#   inflating: flickr30k-images/538638526.jpg
#   inflating: flickr30k-images/5387261695.jpg
#   inflating: flickr30k-images/538825260.jpg
#   inflating: flickr30k-images/5388634274.jpg
#   inflating: flickr30k-images/5388693640.jpg
#   inflating: flickr30k-images/5389294129.jpg
#   inflating: flickr30k-images/538953637.jpg
#   inflating: flickr30k-images/5389902618.jpg
#   inflating: flickr30k-images/538990552.jpg
#   inflating: flickr30k-images/5390483760.jpg
#   inflating: flickr30k-images/539061478.jpg
#   inflating: flickr30k-images/5391079713.jpg
#   inflating: flickr30k-images/5391728144.jpg
#   inflating: flickr30k-images/5392145976.jpg
#   inflating: flickr30k-images/539218410.jpg
#   inflating: flickr30k-images/5393330953.jpg
#   inflating: flickr30k-images/539493423.jpg
#   inflating: flickr30k-images/539493431.jpg
#   inflating: flickr30k-images/53955170.jpg
#   inflating: flickr30k-images/539659873.jpg
#   inflating: flickr30k-images/539667015.jpg
#   inflating: flickr30k-images/539676201.jpg
#   inflating: flickr30k-images/539705321.jpg
#   inflating: flickr30k-images/539744890.jpg
#   inflating: flickr30k-images/539750844.jpg
#   inflating: flickr30k-images/539751252.jpg
#   inflating: flickr30k-images/539761097.jpg
#   inflating: flickr30k-images/5397894822.jpg
#   inflating: flickr30k-images/5397926630.jpg
#   inflating: flickr30k-images/539801139.jpg
#   inflating: flickr30k-images/5398619523.jpg
#   inflating: flickr30k-images/539871204.jpg
#   inflating: flickr30k-images/539881707.jpg
#   inflating: flickr30k-images/5399620276.jpg
#   inflating: flickr30k-images/5400154.jpg
#   inflating: flickr30k-images/5400824262.jpg
#   inflating: flickr30k-images/5402085.jpg
#   inflating: flickr30k-images/5402872122.jpg
#   inflating: flickr30k-images/5403340942.jpg
#   inflating: flickr30k-images/5403366009.jpg
#   inflating: flickr30k-images/5403369219.jpg
#   inflating: flickr30k-images/540338917.jpg
#   inflating: flickr30k-images/5403632578.jpg
#   inflating: flickr30k-images/540381751.jpg
#   inflating: flickr30k-images/5403970454.jpg
#   inflating: flickr30k-images/5403972062.jpg
#   inflating: flickr30k-images/5403974296.jpg
#   inflating: flickr30k-images/5403974988.jpg
#   inflating: flickr30k-images/5403982362.jpg
#   inflating: flickr30k-images/540436324.jpg
#   inflating: flickr30k-images/540436782.jpg
#   inflating: flickr30k-images/5404491005.jpg
#   inflating: flickr30k-images/5404607703.jpg
#   inflating: flickr30k-images/5404931227.jpg
#   inflating: flickr30k-images/5404950935.jpg
#   inflating: flickr30k-images/540503255.jpg
#   inflating: flickr30k-images/5405076022.jpg
#   inflating: flickr30k-images/5405095380.jpg
#   inflating: flickr30k-images/5405152070.jpg
#   inflating: flickr30k-images/5405152538.jpg
#   inflating: flickr30k-images/5405213054.jpg
#   inflating: flickr30k-images/540604040.jpg
#   inflating: flickr30k-images/5406927495.jpg
#   inflating: flickr30k-images/540721368.jpg
#   inflating: flickr30k-images/540746143.jpg
#   inflating: flickr30k-images/540791807.jpg
#   inflating: flickr30k-images/5408196820.jpg
#   inflating: flickr30k-images/5408199015.jpg
#   inflating: flickr30k-images/5408221986.jpg
#   inflating: flickr30k-images/540873795.jpg
#   inflating: flickr30k-images/5408820009.jpg
#   inflating: flickr30k-images/540943543.jpg
#   inflating: flickr30k-images/541046380.jpg
#   inflating: flickr30k-images/5410472318.jpg
#   inflating: flickr30k-images/541063419.jpg
#   inflating: flickr30k-images/541063517.jpg
#   inflating: flickr30k-images/5411481517.jpg
#   inflating: flickr30k-images/5411504795.jpg
#   inflating: flickr30k-images/5412034666.jpg
#   inflating: flickr30k-images/5412119890.jpg
#   inflating: flickr30k-images/541342477.jpg
#   inflating: flickr30k-images/541497191.jpg
#   inflating: flickr30k-images/5415070045.jpg
#   inflating: flickr30k-images/5415181095.jpg
#   inflating: flickr30k-images/541537091.jpg
#   inflating: flickr30k-images/541552675.jpg
#   inflating: flickr30k-images/5415557808.jpg
#   inflating: flickr30k-images/5415557940.jpg
#   inflating: flickr30k-images/5415761675.jpg
#   inflating: flickr30k-images/5415762131.jpg
#   inflating: flickr30k-images/5416301879.jpg
#   inflating: flickr30k-images/5416571561.jpg
#   inflating: flickr30k-images/5416898306.jpg
#   inflating: flickr30k-images/5417456446.jpg
#   inflating: flickr30k-images/5418130134.jpg
#   inflating: flickr30k-images/54185885.jpg
#   inflating: flickr30k-images/5419013581.jpg
#   inflating: flickr30k-images/5419038647.jpg
#   inflating: flickr30k-images/5419695587.jpg
#   inflating: flickr30k-images/5420247403.jpg
#   inflating: flickr30k-images/5420765124.jpg
#   inflating: flickr30k-images/5421108099.jpg
#   inflating: flickr30k-images/542179694.jpg
#   inflating: flickr30k-images/542269487.jpg
#   inflating: flickr30k-images/5423080316.jpg
#   inflating: flickr30k-images/5423102604.jpg
#   inflating: flickr30k-images/542317719.jpg
#   inflating: flickr30k-images/5423856409.jpg
#   inflating: flickr30k-images/542389533.jpg
#   inflating: flickr30k-images/542405691.jpg
#   inflating: flickr30k-images/54242432.jpg
#   inflating: flickr30k-images/5425075136.jpg
#   inflating: flickr30k-images/54260190.jpg
#   inflating: flickr30k-images/542605701.jpg
#   inflating: flickr30k-images/5426416610.jpg
#   inflating: flickr30k-images/542648687.jpg
#   inflating: flickr30k-images/542714962.jpg
#   inflating: flickr30k-images/5428317596.jpg
#   inflating: flickr30k-images/5428390334.jpg
#   inflating: flickr30k-images/542850900.jpg
#   inflating: flickr30k-images/5428747894.jpg
#   inflating: flickr30k-images/5429241344.jpg
#   inflating: flickr30k-images/543007912.jpg
#   inflating: flickr30k-images/5430267989.jpg
#   inflating: flickr30k-images/5430568615.jpg
#   inflating: flickr30k-images/543102698.jpg
#   inflating: flickr30k-images/5431166070.jpg
#   inflating: flickr30k-images/5432374521.jpg
#   inflating: flickr30k-images/543264612.jpg
#   inflating: flickr30k-images/5432673825.jpg
#   inflating: flickr30k-images/543291644.jpg
#   inflating: flickr30k-images/5433157092.jpg
#   inflating: flickr30k-images/543326592.jpg
#   inflating: flickr30k-images/543363241.jpg
#   inflating: flickr30k-images/5434071249.jpg
#   inflating: flickr30k-images/5435865134.jpg
#   inflating: flickr30k-images/543603259.jpg
#   inflating: flickr30k-images/543613917.jpg
#   inflating: flickr30k-images/5436250638.jpg
#   inflating: flickr30k-images/5436553157.jpg
#   inflating: flickr30k-images/5436966915.jpg
#   inflating: flickr30k-images/5436986554.jpg
#   inflating: flickr30k-images/543712974.jpg
#   inflating: flickr30k-images/543797471.jpg
#   inflating: flickr30k-images/5438152388.jpg
#   inflating: flickr30k-images/543875752.jpg
#   inflating: flickr30k-images/543940240.jpg
#   inflating: flickr30k-images/5440115287.jpg
#   inflating: flickr30k-images/544039045.jpg
#   inflating: flickr30k-images/544039061.jpg
#   inflating: flickr30k-images/544046588.jpg
#   inflating: flickr30k-images/544122267.jpg
#   inflating: flickr30k-images/5441246798.jpg
#   inflating: flickr30k-images/5441315625.jpg
#   inflating: flickr30k-images/544149309.jpg
#   inflating: flickr30k-images/5441804056.jpg
#   inflating: flickr30k-images/5442112383.jpg
#   inflating: flickr30k-images/544257613.jpg
#   inflating: flickr30k-images/544301311.jpg
#   inflating: flickr30k-images/5444535493.jpg
#   inflating: flickr30k-images/5444724.jpg
#   inflating: flickr30k-images/5445317867.jpg
#   inflating: flickr30k-images/5445530361.jpg
#   inflating: flickr30k-images/544576742.jpg
#   inflating: flickr30k-images/5446041790.jpg
#   inflating: flickr30k-images/5446138396.jpg
#   inflating: flickr30k-images/5446415631.jpg
#   inflating: flickr30k-images/5447361965.jpg
#   inflating: flickr30k-images/544764927.jpg
#   inflating: flickr30k-images/5447755663.jpg
#   inflating: flickr30k-images/5447844412.jpg
#   inflating: flickr30k-images/54501196.jpg
#   inflating: flickr30k-images/5450688421.jpg
#   inflating: flickr30k-images/5451473560.jpg
#   inflating: flickr30k-images/5452434213.jpg
#   inflating: flickr30k-images/5453323381.jpg
#   inflating: flickr30k-images/5453806694.jpg
#   inflating: flickr30k-images/5453936030.jpg
#   inflating: flickr30k-images/5454221964.jpg
#   inflating: flickr30k-images/5455437647.jpg
#   inflating: flickr30k-images/5455501634.jpg
#   inflating: flickr30k-images/5455508814.jpg
#   inflating: flickr30k-images/5455524571.jpg
#   inflating: flickr30k-images/5456046008.jpg
#   inflating: flickr30k-images/5456725416.jpg
#   inflating: flickr30k-images/5456862756.jpg
#   inflating: flickr30k-images/5457465605.jpg
#   inflating: flickr30k-images/5457524393.jpg
#   inflating: flickr30k-images/5457524513.jpg
#   inflating: flickr30k-images/5457873764.jpg
#   inflating: flickr30k-images/5458061796.jpg
#   inflating: flickr30k-images/5459493511.jpg
#   inflating: flickr30k-images/5460100066.jpg
#   inflating: flickr30k-images/5460845581.jpg
#   inflating: flickr30k-images/5465722830.jpg
#   inflating: flickr30k-images/5466266163.jpg
#   inflating: flickr30k-images/5467111335.jpg
#   inflating: flickr30k-images/5468029953.jpg
#   inflating: flickr30k-images/5468293105.jpg
#   inflating: flickr30k-images/5468460528.jpg
#   inflating: flickr30k-images/5468626430.jpg
#   inflating: flickr30k-images/5469569530.jpg
#   inflating: flickr30k-images/5470620936.jpg
#   inflating: flickr30k-images/54723805.jpg
#   inflating: flickr30k-images/5475015553.jpg
#   inflating: flickr30k-images/5475934236.jpg
#   inflating: flickr30k-images/5476674072.jpg
#   inflating: flickr30k-images/5476688378.jpg
#   inflating: flickr30k-images/5477270023.jpg
#   inflating: flickr30k-images/5477626138.jpg
#   inflating: flickr30k-images/5477639022.jpg
#   inflating: flickr30k-images/5477641512.jpg
#   inflating: flickr30k-images/5479540752.jpg
#   inflating: flickr30k-images/5479743540.jpg
#   inflating: flickr30k-images/5479752383.jpg
#   inflating: flickr30k-images/5480435624.jpg
#   inflating: flickr30k-images/54817316.jpg
#   inflating: flickr30k-images/5482951453.jpg
#   inflating: flickr30k-images/5483441438.jpg
#   inflating: flickr30k-images/5483599902.jpg
#   inflating: flickr30k-images/5484283629.jpg
#   inflating: flickr30k-images/5484875008.jpg
#   inflating: flickr30k-images/5484929515.jpg
#   inflating: flickr30k-images/5485593000.jpg
#   inflating: flickr30k-images/5485896726.jpg
#   inflating: flickr30k-images/5486058256.jpg
#   inflating: flickr30k-images/548751378.jpg
#   inflating: flickr30k-images/5487530231.jpg
#   inflating: flickr30k-images/5488532211.jpg
#   inflating: flickr30k-images/5489135871.jpg
#   inflating: flickr30k-images/5489602545.jpg
#   inflating: flickr30k-images/5491045483.jpg
#   inflating: flickr30k-images/5491397203.jpg
#   inflating: flickr30k-images/5491402223.jpg
#   inflating: flickr30k-images/5491874786.jpg
#   inflating: flickr30k-images/549520317.jpg
#   inflating: flickr30k-images/5495428438.jpg
#   inflating: flickr30k-images/5496383084.jpg
#   inflating: flickr30k-images/5496383618.jpg
#   inflating: flickr30k-images/549639456.jpg
#   inflating: flickr30k-images/549887636.jpg
#   inflating: flickr30k-images/5498941021.jpg
#   inflating: flickr30k-images/549945760.jpg
#   inflating: flickr30k-images/549948800.jpg
#   inflating: flickr30k-images/5499892202.jpg
#   inflating: flickr30k-images/549998716.jpg
#   inflating: flickr30k-images/5500138655.jpg
#   inflating: flickr30k-images/5500650754.jpg
#   inflating: flickr30k-images/5500695312.jpg
#   inflating: flickr30k-images/5500955489.jpg
#   inflating: flickr30k-images/550119995.jpg
#   inflating: flickr30k-images/5501226985.jpg
#   inflating: flickr30k-images/5501235989.jpg
#   inflating: flickr30k-images/5501340599.jpg
#   inflating: flickr30k-images/5501805647.jpg
#   inflating: flickr30k-images/5501819854.jpg
#   inflating: flickr30k-images/5501830558.jpg
#   inflating: flickr30k-images/5501939468.jpg
#   inflating: flickr30k-images/5501939710.jpg
#   inflating: flickr30k-images/5501940668.jpg
#   inflating: flickr30k-images/5502202358.jpg
#   inflating: flickr30k-images/5502929205.jpg
#   inflating: flickr30k-images/5503437581.jpg
#   inflating: flickr30k-images/55034909.jpg
#   inflating: flickr30k-images/5503955724.jpg
#   inflating: flickr30k-images/5504028572.jpg
#   inflating: flickr30k-images/5504365495.jpg
#   inflating: flickr30k-images/5504368601.jpg
#   inflating: flickr30k-images/5504963988.jpg
#   inflating: flickr30k-images/5505219003.jpg
#   inflating: flickr30k-images/550610362.jpg
#   inflating: flickr30k-images/5506383509.jpg
#   inflating: flickr30k-images/5506385451.jpg
#   inflating: flickr30k-images/5506394073.jpg
#   inflating: flickr30k-images/5506395415.jpg
#   inflating: flickr30k-images/5506399373.jpg
#   inflating: flickr30k-images/5506407501.jpg
#   inflating: flickr30k-images/5506988830.jpg
#   inflating: flickr30k-images/5506994278.jpg
#   inflating: flickr30k-images/5507087401.jpg
#   inflating: flickr30k-images/5507574163.jpg
#   inflating: flickr30k-images/5508346028.jpg
#   inflating: flickr30k-images/5508398736.jpg
#   inflating: flickr30k-images/5510073103.jpg
#   inflating: flickr30k-images/5510989691.jpg
#   inflating: flickr30k-images/5511458367.jpg
#   inflating: flickr30k-images/5511459001.jpg
#   inflating: flickr30k-images/5511460259.jpg
#   inflating: flickr30k-images/5511461225.jpg
#   inflating: flickr30k-images/5512062568.jpg
#   inflating: flickr30k-images/551315867.jpg
#   inflating: flickr30k-images/5513216171.jpg
#   inflating: flickr30k-images/55135290.jpg
#   inflating: flickr30k-images/5513727638.jpg
#   inflating: flickr30k-images/551403320.jpg
#   inflating: flickr30k-images/551664516.jpg
#   inflating: flickr30k-images/5517849007.jpg
#   inflating: flickr30k-images/5518762083.jpg
#   inflating: flickr30k-images/5518762299.jpg
#   inflating: flickr30k-images/5518763793.jpg
#   inflating: flickr30k-images/5518764727.jpg
#   inflating: flickr30k-images/5518766647.jpg
#   inflating: flickr30k-images/5519354264.jpg
#   inflating: flickr30k-images/5519356022.jpg
#   inflating: flickr30k-images/5519356488.jpg
#   inflating: flickr30k-images/5519359130.jpg
#   inflating: flickr30k-images/5520203447.jpg
#   inflating: flickr30k-images/5521593413.jpg
#   inflating: flickr30k-images/5521996.jpg
#   inflating: flickr30k-images/5522177900.jpg
#   inflating: flickr30k-images/5522182662.jpg
#   inflating: flickr30k-images/5522482326.jpg
#   inflating: flickr30k-images/5523001543.jpg
#   inflating: flickr30k-images/5523249598.jpg
#   inflating: flickr30k-images/5523538212.jpg
#   inflating: flickr30k-images/5523586446.jpg
#   inflating: flickr30k-images/552498500.jpg
#   inflating: flickr30k-images/5526034.jpg
#   inflating: flickr30k-images/5526424589.jpg
#   inflating: flickr30k-images/5526668006.jpg
#   inflating: flickr30k-images/5526795355.jpg
#   inflating: flickr30k-images/552863655.jpg
#   inflating: flickr30k-images/5529428571.jpg
#   inflating: flickr30k-images/553009435.jpg
#   inflating: flickr30k-images/5532294954.jpg
#   inflating: flickr30k-images/553267106.jpg
#   inflating: flickr30k-images/5533686373.jpg
#   inflating: flickr30k-images/5534272962.jpg
#   inflating: flickr30k-images/5534280202.jpg
#   inflating: flickr30k-images/5534793306.jpg
#   inflating: flickr30k-images/5535626115.jpg
#   inflating: flickr30k-images/5536018727.jpg
#   inflating: flickr30k-images/5536018957.jpg
#   inflating: flickr30k-images/5536107008.jpg
#   inflating: flickr30k-images/5536289343.jpg
#   inflating: flickr30k-images/553854589.jpg
#   inflating: flickr30k-images/55389857.jpg
#   inflating: flickr30k-images/553918837.jpg
#   inflating: flickr30k-images/5539761047.jpg
#   inflating: flickr30k-images/5539804678.jpg
#   inflating: flickr30k-images/55406417.jpg
#   inflating: flickr30k-images/5541308296.jpg
#   inflating: flickr30k-images/5542011192.jpg
#   inflating: flickr30k-images/554215758.jpg
#   inflating: flickr30k-images/5542771977.jpg
#   inflating: flickr30k-images/5543458745.jpg
#   inflating: flickr30k-images/55438559.jpg
#   inflating: flickr30k-images/5543900069.jpg
#   inflating: flickr30k-images/55442802.jpg
#   inflating: flickr30k-images/554526471.jpg
#   inflating: flickr30k-images/55470226.jpg
#   inflating: flickr30k-images/55473406.jpg
#   inflating: flickr30k-images/554774472.jpg
#   inflating: flickr30k-images/5547783051.jpg
#   inflating: flickr30k-images/5549756426.jpg
#   inflating: flickr30k-images/5550039813.jpg
#   inflating: flickr30k-images/555014891.jpg
#   inflating: flickr30k-images/5550325552.jpg
#   inflating: flickr30k-images/5550546246.jpg
#   inflating: flickr30k-images/5551968198.jpg
#   inflating: flickr30k-images/5551993461.jpg
#   inflating: flickr30k-images/555378351.jpg
#   inflating: flickr30k-images/5554366099.jpg
#   inflating: flickr30k-images/5558170783.jpg
#   inflating: flickr30k-images/5558592.jpg
#   inflating: flickr30k-images/5558777621.jpg
#   inflating: flickr30k-images/5559471351.jpg
#   inflating: flickr30k-images/5559644896.jpg
#   inflating: flickr30k-images/5561301943.jpg
#   inflating: flickr30k-images/5562469374.jpg
#   inflating: flickr30k-images/5562975921.jpg
#   inflating: flickr30k-images/5563345549.jpg
#   inflating: flickr30k-images/5563446889.jpg
#   inflating: flickr30k-images/5565536413.jpg
#   inflating: flickr30k-images/5565570899.jpg
#   inflating: flickr30k-images/556568556.jpg
#   inflating: flickr30k-images/556601134.jpg
#   inflating: flickr30k-images/5566135246.jpg
#   inflating: flickr30k-images/5566972.jpg
#   inflating: flickr30k-images/5570219.jpg
#   inflating: flickr30k-images/5570254.jpg
#   inflating: flickr30k-images/557101732.jpg
#   inflating: flickr30k-images/5571017359.jpg
#   inflating: flickr30k-images/5571949283.jpg
#   inflating: flickr30k-images/5572347874.jpg
#   inflating: flickr30k-images/5572351880.jpg
#   inflating: flickr30k-images/5572655622.jpg
#   inflating: flickr30k-images/5573511334.jpg
#   inflating: flickr30k-images/5574382134.jpg
#   inflating: flickr30k-images/557601144.jpg
#   inflating: flickr30k-images/5576659557.jpg
#   inflating: flickr30k-images/557721978.jpg
#   inflating: flickr30k-images/5579811387.jpg
#   inflating: flickr30k-images/5581356064.jpg
#   inflating: flickr30k-images/558161347.jpg
#   inflating: flickr30k-images/5582659196.jpg
#   inflating: flickr30k-images/5582687203.jpg
#   inflating: flickr30k-images/5583005407.jpg
#   inflating: flickr30k-images/5583280537.jpg
#   inflating: flickr30k-images/5583327265.jpg
#   inflating: flickr30k-images/558338473.jpg
#   inflating: flickr30k-images/5583674969.jpg
#   inflating: flickr30k-images/5583837367.jpg
#   inflating: flickr30k-images/5584269779.jpg
#   inflating: flickr30k-images/5584378669.jpg
#   inflating: flickr30k-images/5585791618.jpg
#   inflating: flickr30k-images/5585975540.jpg
#   inflating: flickr30k-images/5586190109.jpg
#   inflating: flickr30k-images/558620122.jpg
#   inflating: flickr30k-images/558665373.jpg
#   inflating: flickr30k-images/5586889028.jpg
#   inflating: flickr30k-images/5587744215.jpg
#   inflating: flickr30k-images/5587932348.jpg
#   inflating: flickr30k-images/5588403950.jpg
#   inflating: flickr30k-images/5589601689.jpg
#   inflating: flickr30k-images/5589693661.jpg
#   inflating: flickr30k-images/5590283636.jpg
#   inflating: flickr30k-images/55903788.jpg
#   inflating: flickr30k-images/559065775.jpg
#   inflating: flickr30k-images/559102835.jpg
#   inflating: flickr30k-images/5591545538.jpg
#   inflating: flickr30k-images/5592562548.jpg
#   inflating: flickr30k-images/5593628279.jpg
#   inflating: flickr30k-images/5593634551.jpg
#   inflating: flickr30k-images/559404730.jpg
#   inflating: flickr30k-images/5594417687.jpg
#   inflating: flickr30k-images/5595611219.jpg
#   inflating: flickr30k-images/5595612913.jpg
#   inflating: flickr30k-images/5597473807.jpg
#   inflating: flickr30k-images/5597767097.jpg
#   inflating: flickr30k-images/5597911580.jpg
#   inflating: flickr30k-images/559852881.jpg
#   inflating: flickr30k-images/559910846.jpg
#   inflating: flickr30k-images/559944506.jpg
#   inflating: flickr30k-images/56012054.jpg
#   inflating: flickr30k-images/56012468.jpg
#   inflating: flickr30k-images/56012911.jpg
#   inflating: flickr30k-images/56013036.jpg
#   inflating: flickr30k-images/5602731697.jpg
#   inflating: flickr30k-images/5602737557.jpg
#   inflating: flickr30k-images/560278886.jpg
#   inflating: flickr30k-images/5603329477.jpg
#   inflating: flickr30k-images/5604836194.jpg
#   inflating: flickr30k-images/5604836629.jpg
#   inflating: flickr30k-images/5604852363.jpg
#   inflating: flickr30k-images/5605133486.jpg
#   inflating: flickr30k-images/5605455443.jpg
#   inflating: flickr30k-images/560671767.jpg
#   inflating: flickr30k-images/5606758706.jpg
#   inflating: flickr30k-images/5608476880.jpg
#   inflating: flickr30k-images/5608502395.jpg
#   inflating: flickr30k-images/5609573810.jpg
#   inflating: flickr30k-images/5610848512.jpg
#   inflating: flickr30k-images/5611391594.jpg
#   inflating: flickr30k-images/5611717202.jpg
#   inflating: flickr30k-images/561179884.jpg
#   inflating: flickr30k-images/561179890.jpg
#   inflating: flickr30k-images/561199893.jpg
#   inflating: flickr30k-images/561204294.jpg
#   inflating: flickr30k-images/5612808611.jpg
#   inflating: flickr30k-images/5613689797.jpg
#   inflating: flickr30k-images/5613922717.jpg
#   inflating: flickr30k-images/561417861.jpg
#   inflating: flickr30k-images/5614228719.jpg
#   inflating: flickr30k-images/5614715384.jpg
#   inflating: flickr30k-images/5615068475.jpg
#   inflating: flickr30k-images/5615077255.jpg
#   inflating: flickr30k-images/5615083329.jpg
#   inflating: flickr30k-images/5615084425.jpg
#   inflating: flickr30k-images/5615134449.jpg
#   inflating: flickr30k-images/5615652514.jpg
#   inflating: flickr30k-images/5615654150.jpg
#   inflating: flickr30k-images/5615654776.jpg
#   inflating: flickr30k-images/5615711650.jpg
#   inflating: flickr30k-images/5615716320.jpg
#   inflating: flickr30k-images/5617549557.jpg
#   inflating: flickr30k-images/561906323.jpg
#   inflating: flickr30k-images/561940436.jpg
#   inflating: flickr30k-images/5620724486.jpg
#   inflating: flickr30k-images/5621180809.jpg
#   inflating: flickr30k-images/5621600104.jpg
#   inflating: flickr30k-images/5621916498.jpg
#   inflating: flickr30k-images/562242613.jpg
#   inflating: flickr30k-images/5622966650.jpg
#   inflating: flickr30k-images/5623287052.jpg
#   inflating: flickr30k-images/5624522.jpg
#   inflating: flickr30k-images/562588230.jpg
#   inflating: flickr30k-images/5626262792.jpg
#   inflating: flickr30k-images/5626622789.jpg
#   inflating: flickr30k-images/562928217.jpg
#   inflating: flickr30k-images/5629300.jpg
#   inflating: flickr30k-images/5629464725.jpg
#   inflating: flickr30k-images/5631556013.jpg
#   inflating: flickr30k-images/5632141892.jpg
#   inflating: flickr30k-images/5633096756.jpg
#   inflating: flickr30k-images/5633231430.jpg
#   inflating: flickr30k-images/5633423671.jpg
#   inflating: flickr30k-images/5633758879.jpg
#   inflating: flickr30k-images/563404108.jpg
#   inflating: flickr30k-images/563508330.jpg
#   inflating: flickr30k-images/5635975939.jpg
#   inflating: flickr30k-images/5637347272.jpg
#   inflating: flickr30k-images/5637361857.jpg
#   inflating: flickr30k-images/5637498751.jpg
#   inflating: flickr30k-images/5637994240.jpg
#   inflating: flickr30k-images/563803038.jpg
#   inflating: flickr30k-images/5639026536.jpg
#   inflating: flickr30k-images/5639106614.jpg
#   inflating: flickr30k-images/5640452539.jpg
#   inflating: flickr30k-images/5641021474.jpg
#   inflating: flickr30k-images/5642901248.jpg
#   inflating: flickr30k-images/5643010407.jpg
#   inflating: flickr30k-images/5645857612.jpg
#   inflating: flickr30k-images/5646792433.jpg
#   inflating: flickr30k-images/5648321.jpg
#   inflating: flickr30k-images/5648828783.jpg
#   inflating: flickr30k-images/5648957534.jpg
#   inflating: flickr30k-images/56489627.jpg
#   inflating: flickr30k-images/56494233.jpg
#   inflating: flickr30k-images/5650197379.jpg
#   inflating: flickr30k-images/565088263.jpg
#   inflating: flickr30k-images/5651210045.jpg
#   inflating: flickr30k-images/5651347663.jpg
#   inflating: flickr30k-images/5651514000.jpg
#   inflating: flickr30k-images/5652699228.jpg
#   inflating: flickr30k-images/565314823.jpg
#   inflating: flickr30k-images/5654749179.jpg
#   inflating: flickr30k-images/5654845057.jpg
#   inflating: flickr30k-images/565490650.jpg
#   inflating: flickr30k-images/565605894.jpg
#   inflating: flickr30k-images/5656207480.jpg
#   inflating: flickr30k-images/5657272299.jpg
#   inflating: flickr30k-images/5657884044.jpg
#   inflating: flickr30k-images/5658123607.jpg
#   inflating: flickr30k-images/5658127907.jpg
#   inflating: flickr30k-images/5660037266.jpg
#   inflating: flickr30k-images/566077886.jpg
#   inflating: flickr30k-images/5661511556.jpg
#   inflating: flickr30k-images/5661511576.jpg
#   inflating: flickr30k-images/5661996549.jpg
#   inflating: flickr30k-images/5662260935.jpg
#   inflating: flickr30k-images/566384456.jpg
#   inflating: flickr30k-images/566397227.jpg
#   inflating: flickr30k-images/566446626.jpg
#   inflating: flickr30k-images/56659639.jpg
#   inflating: flickr30k-images/566794036.jpg
#   inflating: flickr30k-images/566794440.jpg
#   inflating: flickr30k-images/5668948557.jpg
#   inflating: flickr30k-images/566921157.jpg
#   inflating: flickr30k-images/5669382831.jpg
#   inflating: flickr30k-images/566945636.jpg
#   inflating: flickr30k-images/5669914204.jpg
#   inflating: flickr30k-images/5669959908.jpg
#   inflating: flickr30k-images/5671379503.jpg
#   inflating: flickr30k-images/5672704774.jpg
#   inflating: flickr30k-images/567459261.jpg
#   inflating: flickr30k-images/5675148300.jpg
#   inflating: flickr30k-images/567526452.jpg
#   inflating: flickr30k-images/5676066044.jpg
#   inflating: flickr30k-images/5676123641.jpg
#   inflating: flickr30k-images/5676123833.jpg
#   inflating: flickr30k-images/5676780431.jpg
#   inflating: flickr30k-images/5676781835.jpg
#   inflating: flickr30k-images/567713601.jpg
#   inflating: flickr30k-images/5678896414.jpg
#   inflating: flickr30k-images/567903453.jpg
#   inflating: flickr30k-images/567909573.jpg
#   inflating: flickr30k-images/567921691.jpg
#   inflating: flickr30k-images/5679390502.jpg
#   inflating: flickr30k-images/5680345504.jpg
#   inflating: flickr30k-images/5681124098.jpg
#   inflating: flickr30k-images/5681130869.jpg
#   inflating: flickr30k-images/5682364328.jpg
#   inflating: flickr30k-images/5683406436.jpg
#   inflating: flickr30k-images/5683548982.jpg
#   inflating: flickr30k-images/5684145463.jpg
#   inflating: flickr30k-images/5684720360.jpg
#   inflating: flickr30k-images/5684881640.jpg
#   inflating: flickr30k-images/5685007801.jpg
#   inflating: flickr30k-images/5686865855.jpg
#   inflating: flickr30k-images/5686868227.jpg
#   inflating: flickr30k-images/5687357997.jpg
#   inflating: flickr30k-images/568765229.jpg
#   inflating: flickr30k-images/5687832945.jpg
#   inflating: flickr30k-images/5687833791.jpg
#   inflating: flickr30k-images/5687835083.jpg
#   inflating: flickr30k-images/5687835693.jpg
#   inflating: flickr30k-images/5687843849.jpg
#   inflating: flickr30k-images/5687925512.jpg
#   inflating: flickr30k-images/5688558209.jpg
#   inflating: flickr30k-images/568940932.jpg
#   inflating: flickr30k-images/5690228281.jpg
#   inflating: flickr30k-images/5690229093.jpg
#   inflating: flickr30k-images/5690804296.jpg
#   inflating: flickr30k-images/5690859699.jpg
#   inflating: flickr30k-images/5691210724.jpg
#   inflating: flickr30k-images/5691273194.jpg
#   inflating: flickr30k-images/5691273322.jpg
#   inflating: flickr30k-images/5691273582.jpg
#   inflating: flickr30k-images/5691283784.jpg
#   inflating: flickr30k-images/5692076205.jpg
#   inflating: flickr30k-images/5692144392.jpg
#   inflating: flickr30k-images/56927229.jpg
#   inflating: flickr30k-images/5694314894.jpg
#   inflating: flickr30k-images/5695964851.jpg
#   inflating: flickr30k-images/5696547236.jpg
#   inflating: flickr30k-images/5696549500.jpg
#   inflating: flickr30k-images/5696581092.jpg
#   inflating: flickr30k-images/5696880945.jpg
#   inflating: flickr30k-images/5696948391.jpg
#   inflating: flickr30k-images/5701331807.jpg
#   inflating: flickr30k-images/5701726173.jpg
#   inflating: flickr30k-images/5701786491.jpg
#   inflating: flickr30k-images/5703140155.jpg
#   inflating: flickr30k-images/5704623726.jpg
#   inflating: flickr30k-images/570520724.jpg
#   inflating: flickr30k-images/5705242347.jpg
#   inflating: flickr30k-images/5706094499.jpg
#   inflating: flickr30k-images/5706454140.jpg
#   inflating: flickr30k-images/5706580028.jpg
#   inflating: flickr30k-images/57078880.jpg
#   inflating: flickr30k-images/5708913531.jpg
#   inflating: flickr30k-images/5708913719.jpg
#   inflating: flickr30k-images/5709070770.jpg
#   inflating: flickr30k-images/570990225.jpg
#   inflating: flickr30k-images/570996053.jpg
#   inflating: flickr30k-images/570999731.jpg
#   inflating: flickr30k-images/571000535.jpg
#   inflating: flickr30k-images/571002259.jpg
#   inflating: flickr30k-images/5710348031.jpg
#   inflating: flickr30k-images/5710857189.jpg
#   inflating: flickr30k-images/571130875.jpg
#   inflating: flickr30k-images/5712029145.jpg
#   inflating: flickr30k-images/5712096379.jpg
#   inflating: flickr30k-images/5713261883.jpg
#   inflating: flickr30k-images/5714006990.jpg
#   inflating: flickr30k-images/5714048502.jpg
#   inflating: flickr30k-images/571507143.jpg
#   inflating: flickr30k-images/5715657613.jpg
#   inflating: flickr30k-images/571602538.jpg
#   inflating: flickr30k-images/571612606.jpg
#   inflating: flickr30k-images/571621280.jpg
#   inflating: flickr30k-images/5716219952.jpg
#   inflating: flickr30k-images/5716554915.jpg
#   inflating: flickr30k-images/5718253019.jpg
#   inflating: flickr30k-images/571865477.jpg
#   inflating: flickr30k-images/5718656424.jpg
#   inflating: flickr30k-images/57193495.jpg
#   inflating: flickr30k-images/5721131714.jpg
#   inflating: flickr30k-images/5721250516.jpg
#   inflating: flickr30k-images/572135297.jpg
#   inflating: flickr30k-images/5721362205.jpg
#   inflating: flickr30k-images/5721400077.jpg
#   inflating: flickr30k-images/5721468367.jpg
#   inflating: flickr30k-images/572149383.jpg
#   inflating: flickr30k-images/5721495953.jpg
#   inflating: flickr30k-images/5721530415.jpg
#   inflating: flickr30k-images/572163357.jpg
#   inflating: flickr30k-images/572206753.jpg
#   inflating: flickr30k-images/5722658.jpg
#   inflating: flickr30k-images/5723273191.jpg
#   inflating: flickr30k-images/5723818088.jpg
#   inflating: flickr30k-images/5723822388.jpg
#   inflating: flickr30k-images/5726018984.jpg
#   inflating: flickr30k-images/572618443.jpg
#   inflating: flickr30k-images/57264404.jpg
#   inflating: flickr30k-images/5726809479.jpg
#   inflating: flickr30k-images/5726810305.jpg
#   inflating: flickr30k-images/5727359138.jpg
#   inflating: flickr30k-images/572764040.jpg
#   inflating: flickr30k-images/5727946383.jpg
#   inflating: flickr30k-images/5728470160.jpg
#   inflating: flickr30k-images/5728544416.jpg
#   inflating: flickr30k-images/5728602543.jpg
#   inflating: flickr30k-images/5729814.jpg
#   inflating: flickr30k-images/5730196560.jpg
#   inflating: flickr30k-images/5730226613.jpg
#   inflating: flickr30k-images/5730444205.jpg
#   inflating: flickr30k-images/5730564191.jpg
#   inflating: flickr30k-images/5730792187.jpg
#   inflating: flickr30k-images/5731343120.jpg
#   inflating: flickr30k-images/5731856709.jpg
#   inflating: flickr30k-images/5732157460.jpg
#   inflating: flickr30k-images/5732433781.jpg
#   inflating: flickr30k-images/5732659631.jpg
#   inflating: flickr30k-images/5732777684.jpg
#   inflating: flickr30k-images/5733209542.jpg
#   inflating: flickr30k-images/5733760.jpg
#   inflating: flickr30k-images/573385626.jpg
#   inflating: flickr30k-images/5735222957.jpg
#   inflating: flickr30k-images/5735645786.jpg
#   inflating: flickr30k-images/573594802.jpg
#   inflating: flickr30k-images/5737431445.jpg
#   inflating: flickr30k-images/5737434301.jpg
#   inflating: flickr30k-images/5737435305.jpg
#   inflating: flickr30k-images/5737982354.jpg
#   inflating: flickr30k-images/5738179350.jpg
#   inflating: flickr30k-images/5738778049.jpg
#   inflating: flickr30k-images/5738816035.jpg
#   inflating: flickr30k-images/5739332706.jpg
#   inflating: flickr30k-images/5739363696.jpg
#   inflating: flickr30k-images/573946592.jpg
#   inflating: flickr30k-images/5739923608.jpg
#   inflating: flickr30k-images/57417224.jpg
#   inflating: flickr30k-images/57417274.jpg
#   inflating: flickr30k-images/574181.jpg
#   inflating: flickr30k-images/57422853.jpg
#   inflating: flickr30k-images/574274795.jpg
#   inflating: flickr30k-images/5742849511.jpg
#   inflating: flickr30k-images/574306153.jpg
#   inflating: flickr30k-images/5743199540.jpg
#   inflating: flickr30k-images/5743380092.jpg
#   inflating: flickr30k-images/5744253993.jpg
#   inflating: flickr30k-images/5745120660.jpg
#   inflating: flickr30k-images/5745387160.jpg
#   inflating: flickr30k-images/5745422329.jpg
#   inflating: flickr30k-images/5747873823.jpg
#   inflating: flickr30k-images/574793535.jpg
#   inflating: flickr30k-images/5748015019.jpg
#   inflating: flickr30k-images/5748024681.jpg
#   inflating: flickr30k-images/5748029405.jpg
#   inflating: flickr30k-images/5748912722.jpg
#   inflating: flickr30k-images/5749795798.jpg
#   inflating: flickr30k-images/5750611277.jpg
#   inflating: flickr30k-images/5753038227.jpg
#   inflating: flickr30k-images/5753085652.jpg
#   inflating: flickr30k-images/5754249309.jpg
#   inflating: flickr30k-images/57544895.jpg
#   inflating: flickr30k-images/5755891783.jpg
#   inflating: flickr30k-images/575636303.jpg
#   inflating: flickr30k-images/5756366794.jpg
#   inflating: flickr30k-images/575737626.jpg
#   inflating: flickr30k-images/5757492662.jpg
#   inflating: flickr30k-images/5757814392.jpg
#   inflating: flickr30k-images/575853856.jpg
#   inflating: flickr30k-images/5758838589.jpg
#   inflating: flickr30k-images/5759383826.jpg
#   inflating: flickr30k-images/5759427006.jpg
#   inflating: flickr30k-images/5759882364.jpg
#   inflating: flickr30k-images/576075451.jpg
#   inflating: flickr30k-images/576093768.jpg
#   inflating: flickr30k-images/5761090545.jpg
#   inflating: flickr30k-images/5761270577.jpg
#   inflating: flickr30k-images/5761877589.jpg
#   inflating: flickr30k-images/5762196405.jpg
#   inflating: flickr30k-images/5762731952.jpg
#   inflating: flickr30k-images/5766437977.jpg
#   inflating: flickr30k-images/576768199.jpg
#   inflating: flickr30k-images/5767811093.jpg
#   inflating: flickr30k-images/576875301.jpg
#   inflating: flickr30k-images/57691053.jpg
#   inflating: flickr30k-images/576920249.jpg
#   inflating: flickr30k-images/5769574991.jpg
#   inflating: flickr30k-images/5769761872.jpg
#   inflating: flickr30k-images/5769934076.jpg
#   inflating: flickr30k-images/5769937988.jpg
#   inflating: flickr30k-images/5769959745.jpg
#   inflating: flickr30k-images/5769961721.jpg
#   inflating: flickr30k-images/5770115416.jpg
#   inflating: flickr30k-images/5770961200.jpg
#   inflating: flickr30k-images/5771011772.jpg
#   inflating: flickr30k-images/5771078209.jpg
#   inflating: flickr30k-images/5771732.jpg
#   inflating: flickr30k-images/5774624102.jpg
#   inflating: flickr30k-images/5775029982.jpg
#   inflating: flickr30k-images/5776639717.jpg
#   inflating: flickr30k-images/5777129645.jpg
#   inflating: flickr30k-images/5779172980.jpg
#   inflating: flickr30k-images/5780791171.jpg
#   inflating: flickr30k-images/5781162449.jpg
#   inflating: flickr30k-images/578274277.jpg
#   inflating: flickr30k-images/5783690677.jpg
#   inflating: flickr30k-images/5783876648.jpg
#   inflating: flickr30k-images/5784245184.jpg
#   inflating: flickr30k-images/578644583.jpg
#   inflating: flickr30k-images/578679799.jpg
#   inflating: flickr30k-images/5787072819.jpg
#   inflating: flickr30k-images/5788177425.jpg
#   inflating: flickr30k-images/5788678128.jpg
#   inflating: flickr30k-images/5788687372.jpg
#   inflating: flickr30k-images/578873882.jpg
#   inflating: flickr30k-images/5788742746.jpg
#   inflating: flickr30k-images/5788772871.jpg
#   inflating: flickr30k-images/578910261.jpg
#   inflating: flickr30k-images/5789294140.jpg
#   inflating: flickr30k-images/5789670474.jpg
#   inflating: flickr30k-images/578996360.jpg
#   inflating: flickr30k-images/5790434381.jpg
#   inflating: flickr30k-images/579055546.jpg
#   inflating: flickr30k-images/5790840713.jpg
#   inflating: flickr30k-images/5791070.jpg
#   inflating: flickr30k-images/5791244.jpg
#   inflating: flickr30k-images/5791274887.jpg
#   inflating: flickr30k-images/5791568.jpg
#   inflating: flickr30k-images/5793396150.jpg
#   inflating: flickr30k-images/5793422010.jpg
#   inflating: flickr30k-images/5794131663.jpg
#   inflating: flickr30k-images/5794205434.jpg
#   inflating: flickr30k-images/5794346640.jpg
#   inflating: flickr30k-images/5794490455.jpg
#   inflating: flickr30k-images/5796947698.jpg
#   inflating: flickr30k-images/5797618847.jpg
#   inflating: flickr30k-images/5797756884.jpg
#   inflating: flickr30k-images/5797838137.jpg
#   inflating: flickr30k-images/57989758.jpg
#   inflating: flickr30k-images/5802826308.jpg
#   inflating: flickr30k-images/5804672051.jpg
#   inflating: flickr30k-images/58046927.jpg
#   inflating: flickr30k-images/5806030158.jpg
#   inflating: flickr30k-images/5806219410.jpg
#   inflating: flickr30k-images/5806326544.jpg
#   inflating: flickr30k-images/5807099586.jpg
#   inflating: flickr30k-images/5811788459.jpg
#   inflating: flickr30k-images/58121544.jpg
#   inflating: flickr30k-images/5812770731.jpg
#   inflating: flickr30k-images/581419370.jpg
#   inflating: flickr30k-images/581630745.jpg
#   inflating: flickr30k-images/5817561743.jpg
#   inflating: flickr30k-images/58198686.jpg
#   inflating: flickr30k-images/5820828817.jpg
#   inflating: flickr30k-images/5820895953.jpg
#   inflating: flickr30k-images/5821129557.jpg
#   inflating: flickr30k-images/5821135681.jpg
#   inflating: flickr30k-images/5821273614.jpg
#   inflating: flickr30k-images/5821273816.jpg
#   inflating: flickr30k-images/5821457712.jpg
#   inflating: flickr30k-images/5821457818.jpg
#   inflating: flickr30k-images/5822092748.jpg
#   inflating: flickr30k-images/5822381051.jpg
#   inflating: flickr30k-images/5822381095.jpg
#   inflating: flickr30k-images/5822447877.jpg
#   inflating: flickr30k-images/5823012892.jpg
#   inflating: flickr30k-images/5823013198.jpg
#   inflating: flickr30k-images/5823026973.jpg
#   inflating: flickr30k-images/5823145889.jpg
#   inflating: flickr30k-images/5823147109.jpg
#   inflating: flickr30k-images/5823148675.jpg
#   inflating: flickr30k-images/5823151095.jpg
#   inflating: flickr30k-images/5823285867.jpg
#   inflating: flickr30k-images/5823310445.jpg
#   inflating: flickr30k-images/5823326999.jpg
#   inflating: flickr30k-images/5823716566.jpg
#   inflating: flickr30k-images/5823813436.jpg
#   inflating: flickr30k-images/5825226259.jpg
#   inflating: flickr30k-images/5825529550.jpg
#   inflating: flickr30k-images/5826148145.jpg
#   inflating: flickr30k-images/582653438.jpg
#   inflating: flickr30k-images/5826678076.jpg
#   inflating: flickr30k-images/5826844495.jpg
#   inflating: flickr30k-images/582788646.jpg
#   inflating: flickr30k-images/5828028061.jpg
#   inflating: flickr30k-images/582899605.jpg
#   inflating: flickr30k-images/5829317322.jpg
#   inflating: flickr30k-images/5829359094.jpg
#   inflating: flickr30k-images/5829827359.jpg
#   inflating: flickr30k-images/5829835806.jpg
#   inflating: flickr30k-images/583087629.jpg
#   inflating: flickr30k-images/583090328.jpg
#   inflating: flickr30k-images/5831085623.jpg
#   inflating: flickr30k-images/583174725.jpg
#   inflating: flickr30k-images/5831994264.jpg
#   inflating: flickr30k-images/5832821999.jpg
#   inflating: flickr30k-images/5835573414.jpg
#   inflating: flickr30k-images/58357057.jpg
#   inflating: flickr30k-images/5836131322.jpg
#   inflating: flickr30k-images/58363928.jpg
#   inflating: flickr30k-images/58363930.jpg
#   inflating: flickr30k-images/58368365.jpg
#   inflating: flickr30k-images/583865081.jpg
#   inflating: flickr30k-images/5840087663.jpg
#   inflating: flickr30k-images/5840187633.jpg
#   inflating: flickr30k-images/5840232264.jpg
#   inflating: flickr30k-images/5843047066.jpg
#   inflating: flickr30k-images/5843048042.jpg
#   inflating: flickr30k-images/5843164517.jpg
#   inflating: flickr30k-images/5843625835.jpg
#   inflating: flickr30k-images/5843713244.jpg
#   inflating: flickr30k-images/5843921596.jpg
#   inflating: flickr30k-images/584484388.jpg
#   inflating: flickr30k-images/5845214651.jpg
#   inflating: flickr30k-images/5846691766.jpg
#   inflating: flickr30k-images/5846714531.jpg
#   inflating: flickr30k-images/5847006092.jpg
#   inflating: flickr30k-images/584726817.jpg
#   inflating: flickr30k-images/5847719619.jpg
#   inflating: flickr30k-images/5847749710.jpg
#   inflating: flickr30k-images/5848679932.jpg
#   inflating: flickr30k-images/5849278148.jpg
#   inflating: flickr30k-images/5850474494.jpg
#   inflating: flickr30k-images/5851176801.jpg
#   inflating: flickr30k-images/5851818256.jpg
#   inflating: flickr30k-images/5851970989.jpg
#   inflating: flickr30k-images/5852468422.jpg
#   inflating: flickr30k-images/5852667073.jpg
#   inflating: flickr30k-images/5855641283.jpg
#   inflating: flickr30k-images/58579865.jpg
#   inflating: flickr30k-images/5858406299.jpg
#   inflating: flickr30k-images/5858851.jpg
#   inflating: flickr30k-images/5859913309.jpg
#   inflating: flickr30k-images/5861612441.jpg
#   inflating: flickr30k-images/586384606.jpg
#   inflating: flickr30k-images/5865511903.jpg
#   inflating: flickr30k-images/5866079837.jpg
#   inflating: flickr30k-images/5867606.jpg
#   inflating: flickr30k-images/5868688859.jpg
#   inflating: flickr30k-images/5869269064.jpg
#   inflating: flickr30k-images/5870019388.jpg
#   inflating: flickr30k-images/5870433117.jpg
#   inflating: flickr30k-images/5870701819.jpg
#   inflating: flickr30k-images/5871026012.jpg
#   inflating: flickr30k-images/5871124252.jpg
#   inflating: flickr30k-images/5871970.jpg
#   inflating: flickr30k-images/5872331129.jpg
#   inflating: flickr30k-images/58727908.jpg
#   inflating: flickr30k-images/587604325.jpg
#   inflating: flickr30k-images/5876512276.jpg
#   inflating: flickr30k-images/5877914411.jpg
#   inflating: flickr30k-images/5879279230.jpg
#   inflating: flickr30k-images/58803866.jpg
#   inflating: flickr30k-images/5880786104.jpg
#   inflating: flickr30k-images/5881141060.jpg
#   inflating: flickr30k-images/5882565072.jpg
#   inflating: flickr30k-images/5884154559.jpg
#   inflating: flickr30k-images/5884235216.jpg
#   inflating: flickr30k-images/5885058292.jpg
#   inflating: flickr30k-images/5885795251.jpg
#   inflating: flickr30k-images/5885795253.jpg
#   inflating: flickr30k-images/5885865851.jpg
#   inflating: flickr30k-images/58867718.jpg
#   inflating: flickr30k-images/5888131040.jpg
#   inflating: flickr30k-images/5888200593.jpg
#   inflating: flickr30k-images/5888746167.jpg
#   inflating: flickr30k-images/5890401192.jpg
#   inflating: flickr30k-images/5891694046.jpg
#   inflating: flickr30k-images/5891971963.jpg
#   inflating: flickr30k-images/5892888081.jpg
#   inflating: flickr30k-images/5892895879.jpg
#   inflating: flickr30k-images/5892931627.jpg
#   inflating: flickr30k-images/5892947599.jpg
#   inflating: flickr30k-images/5893468050.jpg
#   inflating: flickr30k-images/5893481130.jpg
#   inflating: flickr30k-images/5893485204.jpg
#   inflating: flickr30k-images/5893495086.jpg
#   inflating: flickr30k-images/5893612531.jpg
#   inflating: flickr30k-images/5893948473.jpg
#   inflating: flickr30k-images/5893980467.jpg
#   inflating: flickr30k-images/5894545772.jpg
#   inflating: flickr30k-images/5894551808.jpg
#   inflating: flickr30k-images/58957719.jpg
#   inflating: flickr30k-images/5896386113.jpg
#   inflating: flickr30k-images/5896923627.jpg
#   inflating: flickr30k-images/5897020465.jpg
#   inflating: flickr30k-images/5897050379.jpg
#   inflating: flickr30k-images/5897266539.jpg
#   inflating: flickr30k-images/5897279071.jpg
#   inflating: flickr30k-images/5897297135.jpg
#   inflating: flickr30k-images/5897488202.jpg
#   inflating: flickr30k-images/5897560750.jpg
#   inflating: flickr30k-images/589759896.jpg
#   inflating: flickr30k-images/5897657716.jpg
#   inflating: flickr30k-images/5897700952.jpg
#   inflating: flickr30k-images/5897843552.jpg
#   inflating: flickr30k-images/5897874398.jpg
#   inflating: flickr30k-images/5899467604.jpg
#   inflating: flickr30k-images/5899468014.jpg
#   inflating: flickr30k-images/5899799040.jpg
#   inflating: flickr30k-images/5901845159.jpg
#   inflating: flickr30k-images/5902222408.jpg
#   inflating: flickr30k-images/5902223492.jpg
#   inflating: flickr30k-images/5902372520.jpg
#   inflating: flickr30k-images/5902389941.jpg
#   inflating: flickr30k-images/59027529.jpg
#   inflating: flickr30k-images/5902806140.jpg
# ...
#   inflating: flickr30k-images/865789346.jpg
#   inflating: flickr30k-images/8664920.jpg
#   inflating: flickr30k-images/8664922.jpg
#   inflating: flickr30k-images/866841633.jpg
#   inflating: flickr30k-images/867204263.jpg
#   inflating: flickr30k-images/86729182.jpg
#   inflating: flickr30k-images/86734276.jpg
#   inflating: flickr30k-images/867599993.jpg
#   inflating: flickr30k-images/86800579.jpg
#   inflating: flickr30k-images/8680922.jpg
#   inflating: flickr30k-images/8684718.jpg
#   inflating: flickr30k-images/868984478.jpg
#   inflating: flickr30k-images/86901941.jpg
#   inflating: flickr30k-images/86987116.jpg
#   inflating: flickr30k-images/870186901.jpg
#   inflating: flickr30k-images/870367466.jpg
#   inflating: flickr30k-images/870386962.jpg
#   inflating: flickr30k-images/870710405.jpg
#   inflating: flickr30k-images/87119046.jpg
#   inflating: flickr30k-images/871290646.jpg
#   inflating: flickr30k-images/871290666.jpg
#   inflating: flickr30k-images/871909953.jpg
#   inflating: flickr30k-images/872135364.jpg
#   inflating: flickr30k-images/872512911.jpg
#   inflating: flickr30k-images/872615435.jpg
#   inflating: flickr30k-images/872622575.jpg
#   inflating: flickr30k-images/873633312.jpg
#   inflating: flickr30k-images/873650807.jpg
#   inflating: flickr30k-images/873862583.jpg
#   inflating: flickr30k-images/87388323.jpg
#   inflating: flickr30k-images/873933926.jpg
#   inflating: flickr30k-images/874665322.jpg
#   inflating: flickr30k-images/874736612.jpg
#   inflating: flickr30k-images/875731481.jpg
#   inflating: flickr30k-images/8757787.jpg
#   inflating: flickr30k-images/876493846.jpg
#   inflating: flickr30k-images/876964091.jpg
#   inflating: flickr30k-images/87718618.jpg
#   inflating: flickr30k-images/87761964.jpg
#   inflating: flickr30k-images/878278559.jpg
#   inflating: flickr30k-images/878355466.jpg
#   inflating: flickr30k-images/878758390.jpg
#   inflating: flickr30k-images/87877338.jpg
#   inflating: flickr30k-images/879043160.jpg
#   inflating: flickr30k-images/87938334.jpg
#   inflating: flickr30k-images/87940007.jpg
#   inflating: flickr30k-images/880220939.jpg
#   inflating: flickr30k-images/880663417.jpg
#   inflating: flickr30k-images/880663887.jpg
#   inflating: flickr30k-images/88127430.jpg
#   inflating: flickr30k-images/881336.jpg
#   inflating: flickr30k-images/881383469.jpg
#   inflating: flickr30k-images/881443395.jpg
#   inflating: flickr30k-images/881725588.jpg
#   inflating: flickr30k-images/882048099.jpg
#   inflating: flickr30k-images/88279365.jpg
#   inflating: flickr30k-images/883040210.jpg
#   inflating: flickr30k-images/8832804.jpg
#   inflating: flickr30k-images/88486769.jpg
#   inflating: flickr30k-images/88486961.jpg
#   inflating: flickr30k-images/88488944.jpg
#   inflating: flickr30k-images/8849890.jpg
#   inflating: flickr30k-images/8859482.jpg
#   inflating: flickr30k-images/887108308.jpg
#   inflating: flickr30k-images/88767910.jpg
#   inflating: flickr30k-images/8876934.jpg
#   inflating: flickr30k-images/888244173.jpg
#   inflating: flickr30k-images/888425986.jpg
#   inflating: flickr30k-images/888517718.jpg
#   inflating: flickr30k-images/889751330.jpg
#   inflating: flickr30k-images/890734502.jpg
#   inflating: flickr30k-images/89202781.jpg
#   inflating: flickr30k-images/892340814.jpg
#   inflating: flickr30k-images/89245315.jpg
#   inflating: flickr30k-images/89253626.jpg
#   inflating: flickr30k-images/892870649.jpg
#   inflating: flickr30k-images/89332423.jpg
#   inflating: flickr30k-images/89353191.jpg
#   inflating: flickr30k-images/893808757.jpg
#   inflating: flickr30k-images/89404014.jpg
#   inflating: flickr30k-images/89407459.jpg
#   inflating: flickr30k-images/894928353.jpg
#   inflating: flickr30k-images/894964960.jpg
#   inflating: flickr30k-images/89505897.jpg
#   inflating: flickr30k-images/895359811.jpg
#   inflating: flickr30k-images/895502702.jpg
#   inflating: flickr30k-images/897406883.jpg
#   inflating: flickr30k-images/897621891.jpg
#   inflating: flickr30k-images/89779839.jpg
#   inflating: flickr30k-images/89787769.jpg
#   inflating: flickr30k-images/8990627.jpg
#   inflating: flickr30k-images/899079053.jpg
#   inflating: flickr30k-images/899810584.jpg
#   inflating: flickr30k-images/90011335.jpg
#   inflating: flickr30k-images/900144365.jpg
#   inflating: flickr30k-images/90044984.jpg
#   inflating: flickr30k-images/900557881.jpg
#   inflating: flickr30k-images/90093157.jpg
#   inflating: flickr30k-images/901027462.jpg
#   inflating: flickr30k-images/90123355.jpg
#   inflating: flickr30k-images/90168112.jpg
#   inflating: flickr30k-images/901763909.jpg
#   inflating: flickr30k-images/9035232.jpg
#   inflating: flickr30k-images/90358839.jpg
#   inflating: flickr30k-images/904404695.jpg
#   inflating: flickr30k-images/905022127.jpg
#   inflating: flickr30k-images/905355838.jpg
#   inflating: flickr30k-images/906991263.jpg
#   inflating: flickr30k-images/908636680.jpg
#   inflating: flickr30k-images/909191414.jpg
#   inflating: flickr30k-images/909808296.jpg
#   inflating: flickr30k-images/91083825.jpg
#   inflating: flickr30k-images/911527312.jpg
#   inflating: flickr30k-images/911795495.jpg
#   inflating: flickr30k-images/912382266.jpg
#   inflating: flickr30k-images/912402498.jpg
#   inflating: flickr30k-images/91251257.jpg
#   inflating: flickr30k-images/91365036.jpg
#   inflating: flickr30k-images/915300855.jpg
#   inflating: flickr30k-images/916624251.jpg
#   inflating: flickr30k-images/917574521.jpg
#   inflating: flickr30k-images/91852718.jpg
#   inflating: flickr30k-images/918545497.jpg
#   inflating: flickr30k-images/91875542.jpg
#   inflating: flickr30k-images/918886676.jpg
#   inflating: flickr30k-images/91972799.jpg
#   inflating: flickr30k-images/921190481.jpg
#   inflating: flickr30k-images/92246314.jpg
#   inflating: flickr30k-images/92289076.jpg
#   inflating: flickr30k-images/923550133.jpg
#   inflating: flickr30k-images/92413203.jpg
#   inflating: flickr30k-images/92497263.jpg
#   inflating: flickr30k-images/925491651.jpg
#   inflating: flickr30k-images/92679312.jpg
#   inflating: flickr30k-images/9268793.jpg
#   inflating: flickr30k-images/92732320.jpg
#   inflating: flickr30k-images/927420680.jpg
#   inflating: flickr30k-images/929679367.jpg
#   inflating: flickr30k-images/930126921.jpg
#   inflating: flickr30k-images/930748509.jpg
#   inflating: flickr30k-images/931028778.jpg
#   inflating: flickr30k-images/931156700.jpg
#   inflating: flickr30k-images/9324151.jpg
#   inflating: flickr30k-images/93270842.jpg
#   inflating: flickr30k-images/93307139.jpg
#   inflating: flickr30k-images/93311089.jpg
#   inflating: flickr30k-images/933118213.jpg
#   inflating: flickr30k-images/934028208.jpg
#   inflating: flickr30k-images/93406137.jpg
#   inflating: flickr30k-images/934375844.jpg
#   inflating: flickr30k-images/93447586.jpg
#   inflating: flickr30k-images/937559727.jpg
#   inflating: flickr30k-images/938012664.jpg
#   inflating: flickr30k-images/938162709.jpg
#   inflating: flickr30k-images/938661426.jpg
#   inflating: flickr30k-images/93922153.jpg
#   inflating: flickr30k-images/94024624.jpg
#   inflating: flickr30k-images/94062798.jpg
#   inflating: flickr30k-images/940973925.jpg
#   inflating: flickr30k-images/941641803.jpg
#   inflating: flickr30k-images/94183012.jpg
#   inflating: flickr30k-images/94232465.jpg
#   inflating: flickr30k-images/942399470.jpg
#   inflating: flickr30k-images/9426826.jpg
#   inflating: flickr30k-images/942900552.jpg
#   inflating: flickr30k-images/944374205.jpg
#   inflating: flickr30k-images/944424269.jpg
#   inflating: flickr30k-images/94472195.jpg
#   inflating: flickr30k-images/944788251.jpg
#   inflating: flickr30k-images/944860697.jpg
#   inflating: flickr30k-images/945509052.jpg
#   inflating: flickr30k-images/945555443.jpg
#   inflating: flickr30k-images/946051430.jpg
#   inflating: flickr30k-images/946102063.jpg
#   inflating: flickr30k-images/947664583.jpg
#   inflating: flickr30k-images/947969010.jpg
#   inflating: flickr30k-images/948196883.jpg
#   inflating: flickr30k-images/94987177.jpg
#   inflating: flickr30k-images/94989565.jpg
#   inflating: flickr30k-images/95017523.jpg
#   inflating: flickr30k-images/95021246.jpg
#   inflating: flickr30k-images/95021247.jpg
#   inflating: flickr30k-images/950273886.jpg
#   inflating: flickr30k-images/950411653.jpg
#   inflating: flickr30k-images/95081415.jpg
#   inflating: flickr30k-images/95081629.jpg
#   inflating: flickr30k-images/95151149.jpg
#   inflating: flickr30k-images/952171414.jpg
#   inflating: flickr30k-images/952262215.jpg
#   inflating: flickr30k-images/952352291.jpg
#   inflating: flickr30k-images/952389673.jpg
#   inflating: flickr30k-images/952457689.jpg
#   inflating: flickr30k-images/953036866.jpg
#   inflating: flickr30k-images/953120250.jpg
#   inflating: flickr30k-images/953941506.jpg
#   inflating: flickr30k-images/954987350.jpg
#   inflating: flickr30k-images/9556225.jpg
#   inflating: flickr30k-images/9556226.jpg
#   inflating: flickr30k-images/956164675.jpg
#   inflating: flickr30k-images/957129624.jpg
#   inflating: flickr30k-images/957230475.jpg
#   inflating: flickr30k-images/95728660.jpg
#   inflating: flickr30k-images/95728664.jpg
#   inflating: flickr30k-images/95734035.jpg
#   inflating: flickr30k-images/95734036.jpg
#   inflating: flickr30k-images/95734038.jpg
#   inflating: flickr30k-images/957585444.jpg
#   inflating: flickr30k-images/95758790.jpg
#   inflating: flickr30k-images/957682378.jpg
#   inflating: flickr30k-images/95783195.jpg
#   inflating: flickr30k-images/95795877.jpg
#   inflating: flickr30k-images/958166873.jpg
#   inflating: flickr30k-images/958317706.jpg
#   inflating: flickr30k-images/958326692.jpg
#   inflating: flickr30k-images/95903273.jpg
#   inflating: flickr30k-images/9600569.jpg
#   inflating: flickr30k-images/960092.jpg
#   inflating: flickr30k-images/96022995.jpg
#   inflating: flickr30k-images/96051221.jpg
#   inflating: flickr30k-images/96056569.jpg
#   inflating: flickr30k-images/96059112.jpg
#   inflating: flickr30k-images/96113759.jpg
#   inflating: flickr30k-images/961189263.jpg
#   inflating: flickr30k-images/961220478.jpg
#   inflating: flickr30k-images/961611340.jpg
#   inflating: flickr30k-images/961664774.jpg
#   inflating: flickr30k-images/963730324.jpg
#   inflating: flickr30k-images/9637989.jpg
#   inflating: flickr30k-images/96395587.jpg
#   inflating: flickr30k-images/96399948.jpg
#   inflating: flickr30k-images/964197865.jpg
#   inflating: flickr30k-images/96420612.jpg
#   inflating: flickr30k-images/96421540.jpg
#   inflating: flickr30k-images/964287333.jpg
#   inflating: flickr30k-images/96461750.jpg
#   inflating: flickr30k-images/964871444.jpg
#   inflating: flickr30k-images/965444691.jpg
#   inflating: flickr30k-images/96669857.jpg
#   inflating: flickr30k-images/96692346.jpg
#   inflating: flickr30k-images/966971031.jpg
#   inflating: flickr30k-images/967719295.jpg
#   inflating: flickr30k-images/968081289.jpg
#   inflating: flickr30k-images/96828131.jpg
#   inflating: flickr30k-images/969483211.jpg
#   inflating: flickr30k-images/969655512.jpg
#   inflating: flickr30k-images/96973080.jpg
#   inflating: flickr30k-images/969779007.jpg
#   inflating: flickr30k-images/96978713.jpg
#   inflating: flickr30k-images/96985174.jpg
#   inflating: flickr30k-images/970641406.jpg
#   inflating: flickr30k-images/970958470.jpg
#   inflating: flickr30k-images/97105139.jpg
#   inflating: flickr30k-images/97131520.jpg
#   inflating: flickr30k-images/97138308.jpg
#   inflating: flickr30k-images/97138973.jpg
#   inflating: flickr30k-images/97162852.jpg
#   inflating: flickr30k-images/97233789.jpg
#   inflating: flickr30k-images/97234558.jpg
#   inflating: flickr30k-images/972381743.jpg
#   inflating: flickr30k-images/9726060.jpg
#   inflating: flickr30k-images/973353650.jpg
#   inflating: flickr30k-images/973827791.jpg
#   inflating: flickr30k-images/97406261.jpg
#   inflating: flickr30k-images/974924582.jpg
#   inflating: flickr30k-images/97495047.jpg
#   inflating: flickr30k-images/975131015.jpg
#   inflating: flickr30k-images/97577988.jpg
#   inflating: flickr30k-images/976392326.jpg
#   inflating: flickr30k-images/976414321.jpg
#   inflating: flickr30k-images/976581518.jpg
#   inflating: flickr30k-images/976639041.jpg
#   inflating: flickr30k-images/97731718.jpg
#   inflating: flickr30k-images/977365989.jpg
#   inflating: flickr30k-images/97748313.jpg
#   inflating: flickr30k-images/977856234.jpg
#   inflating: flickr30k-images/977898311.jpg
#   inflating: flickr30k-images/978028673.jpg
#   inflating: flickr30k-images/97825959.jpg
#   inflating: flickr30k-images/978580450.jpg
#   inflating: flickr30k-images/979201222.jpg
#   inflating: flickr30k-images/979383193.jpg
#   inflating: flickr30k-images/97971267.jpg
#   inflating: flickr30k-images/980090465.jpg
#   inflating: flickr30k-images/98023274.jpg
#   inflating: flickr30k-images/980615147.jpg
#   inflating: flickr30k-images/981727078.jpg
#   inflating: flickr30k-images/982013557.jpg
#   inflating: flickr30k-images/98208372.jpg
#   inflating: flickr30k-images/98235403.jpg
#   inflating: flickr30k-images/983396629.jpg
#   inflating: flickr30k-images/98377566.jpg
#   inflating: flickr30k-images/984092829.jpg
#   inflating: flickr30k-images/98415168.jpg
#   inflating: flickr30k-images/98438433.jpg
#   inflating: flickr30k-images/98492339.jpg
#   inflating: flickr30k-images/984950.jpg
#   inflating: flickr30k-images/985067019.jpg
#   inflating: flickr30k-images/98557260.jpg
#   inflating: flickr30k-images/985982384.jpg
#   inflating: flickr30k-images/986127455.jpg
#   inflating: flickr30k-images/986440271.jpg
#   inflating: flickr30k-images/987442144.jpg
#   inflating: flickr30k-images/98756067.jpg
#   inflating: flickr30k-images/98756125.jpg
#   inflating: flickr30k-images/98773047.jpg
#   inflating: flickr30k-images/987907964.jpg
#   inflating: flickr30k-images/98817947.jpg
#   inflating: flickr30k-images/98885561.jpg
#   inflating: flickr30k-images/98944492.jpg
#   inflating: flickr30k-images/989754491.jpg
#   inflating: flickr30k-images/989851184.jpg
#   inflating: flickr30k-images/990890291.jpg
#   inflating: flickr30k-images/991459749.jpg
#   inflating: flickr30k-images/991459823.jpg
#   inflating: flickr30k-images/99171998.jpg
#   inflating: flickr30k-images/991971859.jpg
#   inflating: flickr30k-images/99458430.jpg
#   inflating: flickr30k-images/9950858.jpg
#   inflating: flickr30k-images/9950913.jpg
#   inflating: flickr30k-images/996089206.jpg
#   inflating: flickr30k-images/996712323.jpg
#   inflating: flickr30k-images/99679241.jpg
#   inflating: flickr30k-images/996962407.jpg
#   inflating: flickr30k-images/997338199.jpg
#   inflating: flickr30k-images/997722733.jpg
#   inflating: flickr30k-images/997876722.jpg
#   inflating: flickr30k-images/99804383.jpg
#   inflating: flickr30k-images/998845445.jpg
#   inflating: flickr30k-images/readme.txt
# --2023-07-29 14:43:26--  http://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip
# Resolving cs.stanford.edu (cs.stanford.edu)... 171.64.64.64
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip [following]
# --2023-07-29 14:43:26--  https://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36745453 (35M) [application/zip]
# Saving to: ‘caption_datasets.zip’
#
# caption_datasets.zi 100%[===================>]  35.04M  11.5MB/s    in 3.1s
#
# 2023-07-29 14:43:30 (11.5 MB/s) - ‘caption_datasets.zip’ saved [36745453/36745453]
#
# Archive:  caption_datasets.zip
#   inflating: dataset_coco.json
#   inflating: dataset_flickr30k.json
#   inflating: dataset_flickr8k.json

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import os
import sys
import json
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import skimage.transform
from PIL import Image
from collections import Counter
from tqdm.notebook import tqdm

import torch
import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pack_padded_sequence
from nltk.translate.bleu_score import corpus_bleu

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Preprocessing and Loading

# %%
print("# of images [training]: {}".format(len(os.listdir("flickr30k-images"))))
#print("# of images [validation]: {}".format(len(os.listdir("val2014"))))
# Out:
# # of images [training]: 31784

# %%
with open('dataset_flickr30k.json', 'r') as f:
    data = json.load(f)
max_len = 100               # length of padded captions
image_folder = '/content/flickr30k-images'   # folder with download images for train and val set
min_word_freq = 5           # words occuring less than this threshold will be labelled as <unk>
captions_per_image = 5      # number of captions per image
word_freq = Counter()       # Counter object to find the freq of each word

# generate word map
for img in data['images']:
    for c in img['sentences']:
        # update word frequency
        word_freq.update(c['tokens'])

# create word map (dict mapping words to ids with 0 reserved for padding)
words = [word for word in word_freq.keys() if word_freq[word] > min_word_freq]
word2id = {word: id for id, word in enumerate(words, 1)}
word2id['<unk>'] = len(word2id) + 1
word2id['<start>'] = len(word2id) + 1
word2id['<end>'] = len(word2id) + 1
word2id['<pad>'] = 0

# create reverse word map (dict mapping ids to words)
id2word = {value: word for word, value in word2id.items()}

# %%
print(len(word2id))
# Out:
# 7003

# %%
# split the images and captions into train, val and test
train_image_paths = []
train_image_captions = []
train_caption_lens = []

val_image_paths = []
val_image_captions = []
val_caption_lens = []

test_image_paths = []
test_image_captions = []
test_caption_lens = []

for img in data['images']:
    captions = []
    for c in img['sentences']:
        if len(c['tokens']) <= max_len:
            captions.append(c['tokens'])

    if len(captions) == 0:
        continue

    # sample the captions randomly such that every image has same no of captions
    if len(captions) < captions_per_image:
        captions += [random.choice(captions) for _ in range(captions_per_image - len(captions))]
    else:
        captions = random.sample(captions, k=captions_per_image)

    # sanity check
    assert len(captions) == captions_per_image

    # encode and pad captions
    enc_captions = []
    caption_lens = []
    for idx, caption in enumerate(captions):
        enc_caption = [word2id['<start>']] + [word2id.get(word, word2id['<unk>']) for word in caption] + [
                        word2id['<end>']] + [word2id['<pad>']] * (max_len - len(caption))

        # find caption length (including start and end token)
        caption_len = len(caption) + 2

        enc_captions.append(enc_caption)
        caption_lens.append(caption_len)

    # get the absolute path of image
    path = os.path.join(image_folder, img['filename'])

    # add the image path, encoded caption to the list
    if img['split'] in {'train', 'restval'}:
        train_image_paths.append(path)
        train_image_captions.append(enc_captions)
        train_caption_lens.append(caption_lens)
    elif img['split'] in {'val'}:
        val_image_paths.append(path)
        val_image_captions.append(enc_captions)
        val_caption_lens.append(caption_lens)
    elif img['split'] in {'test'}:
        test_image_paths.append(path)
        test_image_captions.append(enc_captions)
        test_caption_lens.append(caption_lens)

# sanity check
assert len(train_image_paths) == len(train_image_captions)
assert len(val_image_paths) == len(val_image_captions)
assert len(test_image_paths) == len(test_image_captions)

# %%
# sets device to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def crop_center(img, cropx, cropy):
    c,y,x = img.shape
    img_ = []
    for i in range(c):
        startx = x//2-(cropx//2)
        starty = y//2-(cropy//2)
        img_.append(img[i][starty:starty+cropy,startx:startx+cropx])
    return np.array(img_)

# %%
class CaptionDataset(Dataset):
    def __init__(self, image_paths, captions, caption_lens, split, captions_per_image=5, transform=None):
        self.split = split
        assert self.split in {'TRAIN', 'VAL', 'TEST'}

        self.image_paths = image_paths
        self.captions = captions
        self.caption_lens = caption_lens
        self.captions_per_image = captions_per_image

        # pytorch transformation pipeline for image (normalizing, etc)
        self.transform = transform

    def __len__(self):
        return len(self.image_paths) * self.captions_per_image

    def __getitem__(self, idx):
        # remember the Nth caption belongs to (N // captions_per_image)th image
        img = Image.open(self.image_paths[idx // self.captions_per_image]).convert('RGB')
        img = np.array(img)
        img = cv2.resize(img, (256, 256))

        # sanity check
        assert img.shape == (256, 256, 3)
        assert np.max(img) <= 255.

        img = np.array(img)
        img = np.transpose(img, (2, 0, 1))
        img = crop_center(img, 224, 224)
        img = torch.FloatTensor(img/255.)
        if self.transform is not None:
            img = self.transform(img)
        caption = torch.LongTensor(self.captions[idx // self.captions_per_image][idx % self.captions_per_image])
        caption_len = torch.LongTensor([self.caption_lens[idx // self.captions_per_image][idx % self.captions_per_image]])

        if self.split is 'TRAIN':
            return img, caption, caption_len
        else:
            # return all captions per image for validation or testing to find the BLEU-4 scores
            all_captions = torch.LongTensor(self.captions[idx // self.captions_per_image])
            return img, caption, caption_len, all_captions


transform = transforms.Compose([
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
train_dataset = CaptionDataset(train_image_paths, train_image_captions, train_caption_lens, 'TRAIN',transform=transform)
val_dataset = CaptionDataset(val_image_paths, val_image_captions, val_caption_lens, 'VAL',transform=transform)
test_dataset = CaptionDataset(test_image_paths, test_image_captions, test_caption_lens, 'TEST',transform=transform)

# %% [markdown]
# ### Visualize data

# %%
def decode_caption(enc_caption):
    dec_caption = [
        id2word[id]
        for id in caption.numpy()
        if id2word[id] not in ["<start>", "<end>", "<unk>", "<pad>"]
    ]
    return " ".join(dec_caption)

# %%
img, caption, caption_len = train_dataset[0]

print(decode_caption(caption))
print()
plt.imshow(img.permute(1, 2, 0));
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# two young guys with shaggy hair look at their hands while hanging out in the yard

# %%
img, caption, caption_len, all_captions = val_dataset[0]

for caption in all_captions:
    print(decode_caption(caption))
print()
plt.imshow(img.permute(1, 2, 0));
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# a group of men are loading cotton onto a truck
# a group of people stand in the back of a truck filled with cotton
# a group of people are standing on a pile of wool in a truck
# workers load wool onto a truck
# men are standing on and about a truck carrying a white substance

# %%
batch_size = 32
workers = 2

# dataloader for train and val set
train_loader = DataLoader(train_dataset, batch_size=batch_size,
                          shuffle=True, num_workers=workers, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size,
                          shuffle=True, num_workers=workers, pin_memory=True)

# quick check to see if data is properly loaded or not
images, captions, caption_lens = next(iter(train_loader))
print(images.shape)
print(captions.shape)
print(caption_lens.shape)
# Out:
# torch.Size([32, 3, 224, 224])
# torch.Size([32, 102])
# torch.Size([32, 1])

# %% [markdown]
# ## Model Architecture

# %%
class ImageEncoder(nn.Module):
    def __init__(self, enc_image_size=14):
        super(ImageEncoder, self).__init__()
        self.enc_image_size = enc_image_size

        # pretrained ImageNet ResNet-101
        resnet = torchvision.models.resnet50(pretrained=True)

        # remove linear and pool layers
        modules = list(resnet.children())[:-2]
        self.resnet = nn.Sequential(*modules)

        # resize image to fixed size using adaptive pool to allow input images of variable size
        self.adaptive_pool = nn.AdaptiveAvgPool2d((enc_image_size, enc_image_size))

        self.fine_tune()

    def fine_tune(self, fine_tune=True):
        """
        Allow or prevent computation of the gradients for convolutional blocks 2 through 4 of the image encoder.
        :param fine_tune: boolean
        """
        for param in self.resnet.parameters():
            param.requires_grad = False
        #if fine-tuning, fine-tune convolutional blocks 2 through 4
        for child in list(self.resnet.children())[5:]:
            for param in child.parameters():
                param.requires_grad = fine_tune

    def forward(self, images):
        """
        Forward propagation.
        :param images: images, a tensor of dim (batch_size, 3, image_size, image_size)
        :return enc_images: encoded repr of images, a tensor of dim (batch_size, enc_image_size, enc_image_size, 2048)
        """
        out = self.resnet(images)       # (batch_size, 2048, image_size/32, image_size/32)
        out = self.adaptive_pool(out)   # (batch_size, 2048, enc_image_size, enc_image_size)
        out = out.permute(0, 2, 3, 1)   # (batch_size, enc_image_size, enc_image_size, 2048)
        return out

# %%
class Decoder(nn.Module):
    """
    Decoder.
    """

    def __init__(self, embed_dim, decoder_dim, vocab_size, encoder_dim=2048, dropout=0.5):
        """
        :param embed_dim: embedding size
        :param decoder_dim: size of decoder's RNN
        :param vocab_size: size of vocabulary
        :param encoder_dim: feature size of encoded images
        :param dropout: dropout
        """
        super(Decoder, self).__init__()

        self.encoder_dim = encoder_dim
        self.embed_dim = embed_dim
        self.decoder_dim = decoder_dim
        self.vocab_size = vocab_size
        self.dropout = dropout

        self.embedding = nn.Embedding(vocab_size, embed_dim)  # embedding layer
        self.dropout = nn.Dropout(p=self.dropout)
        self.decode_step = nn.LSTMCell(embed_dim, decoder_dim, bias=True)  # decoding LSTMCell
        self.init_h = nn.Linear(encoder_dim, decoder_dim)  # linear layer to find initial hidden state of LSTMCell
        self.init_c = nn.Linear(encoder_dim, decoder_dim)  # linear layer to find initial cell state of LSTMCell
        self.f_beta = nn.Linear(decoder_dim, encoder_dim)  # linear layer to create a sigmoid-activated gate
        self.sigmoid = nn.Sigmoid()
        self.fc = nn.Linear(decoder_dim, vocab_size)  # linear layer to find scores over vocabulary
        self.init_weights()  # initialize some layers with the uniform distribution

    def init_weights(self):
        """
        Initializes some parameters with values from the uniform distribution, for easier convergence.
        """
        self.embedding.weight.data.uniform_(-0.1, 0.1)
        self.fc.bias.data.fill_(0)
        self.fc.weight.data.uniform_(-0.1, 0.1)

    def load_pretrained_embeddings(self, embeddings):
        """
        Loads embedding layer with pre-trained embeddings.

        :param embeddings: pre-trained embeddings
        """
        self.embedding.weight = nn.Parameter(embeddings)

    def fine_tune_embeddings(self, fine_tune=True):
        """
        Allow fine-tuning of embedding layer? (Only makes sense to not-allow if using pre-trained embeddings).

        :param fine_tune: Allow?
        """
        for p in self.embedding.parameters():
            p.requires_grad = fine_tune

    def init_hidden_state(self, encoder_out):
        """
        Creates the initial hidden and cell states for the decoder's LSTM based on the encoded images.

        :param encoder_out: encoded images, a tensor of dimension (batch_size, num_pixels, encoder_dim)
        :return: hidden state, cell state
        """
        mean_encoder_out = encoder_out.mean(dim=1)
        h = self.init_h(mean_encoder_out)  # (batch_size, decoder_dim)
        c = self.init_c(mean_encoder_out)
        return h, c

    def forward(self, encoder_out, encoded_captions, caption_lengths):
        """
        Forward propagation.

        :param encoder_out: encoded images, a tensor of dimension (batch_size, enc_image_size, enc_image_size, encoder_dim)
        :param encoded_captions: encoded captions, a tensor of dimension (batch_size, max_caption_length)
        :param caption_lengths: caption lengths, a tensor of dimension (batch_size, 1)
        :return: scores for vocabulary, sorted encoded captions, decode lengths, weights, sort indices
        """

        batch_size = encoder_out.size(0)
        encoder_dim = encoder_out.size(-1)
        vocab_size = self.vocab_size

        # Flatten image
        encoder_out = encoder_out.view(batch_size, -1, encoder_dim)  # (batch_size, num_pixels, encoder_dim)
        num_pixels = encoder_out.size(1)

        # Sort input data by decreasing lengths; why? apparent below
        caption_lengths, sort_ind = caption_lengths.squeeze(1).sort(dim=0, descending=True)
        encoder_out = encoder_out[sort_ind]
        encoded_captions = encoded_captions[sort_ind]

        # Embedding
        embeddings = self.embedding(encoded_captions)  # (batch_size, max_caption_length, embed_dim)

        # Initialize LSTM state
        h, c = self.init_hidden_state(encoder_out)  # (batch_size, decoder_dim)

        # We won't decode at the <end> position, since we've finished generating as soon as we generate <end>
        # So, decoding lengths are actual lengths - 1
        decode_lengths = (caption_lengths - 1).tolist()

        # Create tensors to hold word predicion scores
        predictions = torch.zeros(batch_size, max(decode_lengths), vocab_size).to(device)

        # At each time-step, decode by
        for t in range(max(decode_lengths)):
            batch_size_t = sum([l > t for l in decode_lengths])
            h, c = self.decode_step(embeddings[:batch_size_t, t, :], (h[:batch_size_t], c[:batch_size_t]))  # (batch_size_t, decoder_dim)
            preds = self.fc(self.dropout(h))  # (batch_size_t, vocab_size)
            predictions[:batch_size_t, t, :] = preds

        return predictions, encoded_captions, decode_lengths, sort_ind

# %% [markdown]
# ## Helper Utility functions

# %%
def accuracy(scores, targets, k):
    """
    Computes top-k accuracy, from predicted and true labels.
    :param scores: scores from the model
    :param targets: true labels
    :param k: k in top-k accuracy
    :return: top-k accuracy
    """

    batch_size = targets.size(0)
    _, ind = scores.topk(k, 1, True, True)
    correct = ind.eq(targets.view(-1, 1).expand_as(ind))
    correct_total = correct.view(-1).float().sum()  # 0D tensor
    return correct_total.item() * (100.0 / batch_size)

# %%
def clip_gradient(optimizer, grad_clip):
    """
    Clips gradients computed during backpropagation to avoid explosion of gradients.
    :param optimizer: optimizer with the gradients to be clipped
    :param grad_clip: clip value
    """
    for group in optimizer.param_groups:
        for param in group['params']:
            if param.grad is not None:
                param.grad.data.clamp_(-grad_clip, grad_clip)

# %%
def save_checkpoint(epoch, epochs_since_improvement, encoder, decoder, encoder_optimizer, decoder_optimizer,
                    bleu4, is_best):
    """
    Saves model checkpoint.
    :param epoch: epoch number
    :param epochs_since_improvement: number of epochs since last improvement in BLEU-4 score
    :param encoder: encoder model
    :param decoder: decoder model
    :param encoder_optimizer: optimizer to update encoder's weights, if fine-tuning
    :param decoder_optimizer: optimizer to update decoder's weights
    :param bleu4: validation BLEU-4 score for this epoch
    :param is_best: is this checkpoint the best so far?
    """
    state = {
        'epoch': epoch,
        'epochs_since_improvement': epochs_since_improvement,
        'bleu-4': bleu4,
        'encoder': encoder,
        'decoder': decoder,
        'encoder_optimizer': encoder_optimizer,
        'decoder_optimizer': decoder_optimizer
    }
    filename = 'image_captioning_checkpoint_' + str(epoch) + '.pth'
    torch.save(state, filename)
    # store the copy of best checkpoint
    if is_best:
        print('Saving the best model')
        torch.save(state, './drive/MyDrive/image_captioning/'+'image_captioning_best_30k_noattention.pth')

# %% [markdown]
# ## Training

# %%
def train_epoch(train_loader, encoder, decoder, criterion, encoder_optimizer, decoder_optimizer):
    """
    Performs one epoch's training.
    :param train_loader: DataLoader for training data
    :param encoder: encoder model
    :param decoder: decoder model
    :param criterion: loss layer
    :param encoder_optimizer: optimizer to update encoder's weights (if fine-tuning)
    :param decoder_optimizer: optimizer to update decoder's weights
    :param epoch: epoch number
    """
    losses = []
    top5accs = []

    # train mode (dropout and batchnorm is used)
    decoder.train()
    encoder.train()

    for i, (imgs, caps, cap_lens) in enumerate(tqdm(train_loader, total=len(train_loader))):
        # move tensor to GPU if available
        imgs = imgs.to(device)
        caps = caps.to(device)
        cap_lens = cap_lens.to(device)

        # forward prop
        imgs = encoder(imgs)
        scores, caps_sorted, decode_lengths, sort_ind = decoder(imgs, caps, cap_lens)

        # since we decoded starting with <start>, the targets are all words after <start>, up to <end>
        targets = caps_sorted[:, 1:]

        # remove timesteps that we didn't decode at, or are pads
        scores = pack_padded_sequence(scores, decode_lengths, batch_first=True).data
        targets = pack_padded_sequence(targets, decode_lengths, batch_first=True).data

        # calculate the loss
        loss = criterion(scores, targets)

        # backprop
        decoder_optimizer.zero_grad()
        if encoder_optimizer is not None:
            encoder_optimizer.zero_grad()
        loss.backward()

        # clip gradients
        if grad_clip is not None:
            clip_gradient(decoder_optimizer, grad_clip)
            if encoder_optimizer is not None:
                clip_gradient(encoder_optimizer, grad_clip)

        # update weights
        decoder_optimizer.step()
        if encoder_optimizer is not None:
            encoder_optimizer.step()

        # keep track of metrics
        top5 = accuracy(scores, targets, 5)
        losses.append(loss.item())
        top5accs.append(top5)

    return np.mean(losses), np.mean(top5accs)

# %%
def val_epoch(val_loader, encoder, decoder, criterion):
    """
    Performs one epoch's validation.
    :param val_loader: DataLoader for validation data.
    :param encoder: encoder model
    :param decoder: decoder model
    :param criterion: loss layer
    :return: BLEU-4 score
    """
    losses = []
    top5accs = []

    # eval mode (no dropout or batchnorm)
    decoder.eval()
    if encoder is not None:
        encoder.eval()

    references = list()  # references (true captions) for calculating BLEU-4 score
    hypotheses = list()  # hypotheses (predictions)

    # explicitly disable gradient calculation
    with torch.no_grad():
        for i, (imgs, caps, cap_lens, all_caps) in enumerate(tqdm(val_loader, total=len(val_loader))):
            # move tensor to GPU if available
            imgs = imgs.to(device)
            caps = caps.to(device)
            cap_lens = cap_lens.to(device)

            # forward prop
            imgs = encoder(imgs)
            scores, caps_sorted, decode_lengths, sort_ind = decoder(imgs, caps, cap_lens)

            # since we decoded starting with <start>, the targets are all words after <start>, up to <end>
            targets = caps_sorted[:, 1:]

            # remove timesteps that we didn't decode at, or are pads
            scores_copy = scores.clone()
            scores = pack_padded_sequence(scores, decode_lengths, batch_first=True).data
            targets = pack_padded_sequence(targets, decode_lengths, batch_first=True).data

            # calculate the loss
            loss = criterion(scores, targets)

            # keep track of metrics
            top5 = accuracy(scores, targets, 5)
            losses.append(loss.item())
            top5accs.append(top5)

            # Store references (true captions), and hypothesis (prediction) for each image
            # If for n images, we have n hypotheses, and references a, b, c... for each image, we need -
            # references = [[ref1a, ref1b, ref1c], [ref2a, ref2b], ...], hypotheses = [hyp1, hyp2, ...]

            # references
            all_caps = all_caps.to(sort_ind.device)[sort_ind]  # because images were sorted in the decoder
            for j in range(all_caps.shape[0]):
                img_caps = all_caps[j].tolist()
                img_captions = list(
                    map(lambda caption: [word for word in caption if word not in {word2id['<start>'], word2id['<pad>']}],
                        img_caps))  # remove <start> and pads
                references.append(img_captions)

            # hypotheses
            _, preds = torch.max(scores_copy, dim=2)
            preds = preds.tolist()
            temp_preds = list()
            for j, pred in enumerate(preds):
                temp_preds.append(preds[j][:decode_lengths[j]])  # remove pads
            hypotheses.extend(temp_preds)

            # sanity check
            assert len(references) == len(hypotheses)

        # calculate BLEU-4 scores
        bleu4 = corpus_bleu(references, hypotheses)

    return np.mean(losses), np.mean(top5accs), bleu4

# %%
# model parameters
embed_dim = 512      # dimension of word embeddings
attention_dim = 512  # dimension of attention linear layers
decoder_dim = 512    # dimension of decoder RNN
encoder_dim = 2048
encoder_lr = 1e-4  # learning rate for encoder if fine-tuning
decoder_lr = 4e-4  # learning rate for decoder
grad_clip = 5.  # clip gradients at an absolute value of
alpha_c = 1.  # regularization parameter for 'doubly stochastic attention', as in the paper
vocab_size = len(word2id)
best_bleu4 = 0.  # BLEU-4 score right now
lr_decay_factor = 0.8
lr_decay_patience = 8
best_bleu4 = 0

start_epoch = 1
num_epochs = 120
epochs_since_improvement = 0  # keeps track of number of epochs since there's been an improvement in validation BLEU

fine_tune_encoder = True  # fine-tune encoder?
checkpoint = './drive/MyDrive/image_captioning/'+'image_captioning_best_30k_noattention.pth'  # image_captioning_best.pth
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead


# checkpoint
if checkpoint is None:
    decoder = Decoder(embed_dim, decoder_dim, vocab_size, encoder_dim)
    decoder_optimizer = optim.Adam(params=filter(lambda p: p.requires_grad, decoder.parameters()), lr=decoder_lr)
    #decoder_optimizer = torch.optim.RMSprop(params=filter(lambda p: p.requires_grad, decoder.parameters()), lr=decoder_lr)
    encoder = ImageEncoder()
    encoder.fine_tune(fine_tune_encoder)
    encoder_optimizer = optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()), lr=encoder_lr) if fine_tune_encoder else None

else:
    checkpoint = torch.load(checkpoint)

    start_epoch = checkpoint['epoch'] + 1
    best_bleu4 = checkpoint['bleu-4']
    encoder = checkpoint['encoder']
    decoder = checkpoint['decoder']
    encoder_optimizer = checkpoint['encoder_optimizer']
    decoder_optimizer = checkpoint['decoder_optimizer']

    if fine_tune_encoder is True and encoder_optimizer is None:
        encoder.fine_tune(fine_tune_encoder)
        encoder_optimizer = optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()), lr=encoder_lr)


encoder = encoder.to(device)
decoder = decoder.to(device)

# lr scheduler
encoder_lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(encoder_optimizer, mode='max', factor=lr_decay_factor, patience=lr_decay_patience) if fine_tune_encoder else None
decoder_lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(decoder_optimizer, mode='max', factor=lr_decay_factor, patience=lr_decay_patience)

# criterion for loss
criterion = nn.CrossEntropyLoss().to(device)

# loop
for epoch in range(start_epoch, num_epochs + 1):
    loss_train, acc_train = train_epoch(train_loader, encoder, decoder, criterion, encoder_optimizer, decoder_optimizer)
    loss_val, acc_val, bleu4_val = val_epoch(val_loader, encoder, decoder, criterion)

    # reduce the learning rate on plateau
    decoder_lr_scheduler.step(bleu4_val)
    if fine_tune_encoder:
        encoder_lr_scheduler.step(bleu4_val)

    # check if there was an improvement
    is_best = bleu4_val > best_bleu4
    best_bleu4 = max(bleu4_val, best_bleu4)
    if not is_best:
        epochs_since_improvement += 1
    else:
        epochs_since_improvement = 0

    print('-' * 40)
    print(f'epoch: {epoch}, train loss: {loss_train:.4f}, train acc: {acc_train:.2f}%, valid loss: {loss_val:.4f}, valid acc: {acc_val:.2f}%, best BLEU-4: {best_bleu4:.4f}')
    print('-' * 40)

    # save the checkpoint
    save_checkpoint(epoch, epochs_since_improvement, encoder, decoder, encoder_optimizer,
                    decoder_optimizer, bleu4_val, is_best)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-09843cdda617> in <cell line: 26>()
#      33
#      34 else:
# ---> 35     checkpoint = torch.load(checkpoint)
#      36
#      37     start_epoch = checkpoint['epoch'] + 1
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     789         pickle_load_args['encoding'] = 'utf-8'
#     790
# --> 791     with _open_file_like(f, 'rb') as opened_file:
#     792         if _is_zipfile(opened_file):
#     793             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     250 class _open_file(_opener):
#     251     def __init__(self, name, mode):
# --> 252         super().__init__(open(name, mode))
#     253
#     254     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: './drive/MyDrive/image_captioning/image_captioning_best_30k_noattention.pth'

# %% [markdown]
# ## Generate captions for test set

# %%
def generate_image_caption_noattention(encoder, decoder, image_path, word_map, beam_size=5):
    """
    Reads an image and captions it with beam search as well as plot attention maps.
    """
    k = beam_size

    # id to word mapping
    rev_word_map = {id: word for word, id in word_map.items()}

    # read and pre-process image
    img = np.array(Image.open(image_path).convert('RGB'))
    img = np.array(Image.open(image_path).convert('RGB'))
    img = cv2.resize(img, (256, 256))

    # sanity check
    assert img.shape == (256, 256, 3)
    assert np.max(img) <= 255
    img = img.transpose(2, 0, 1)
    img = crop_center(img, 224, 224)
    img = img / 255.
    img = torch.FloatTensor(img)
    transform = transforms.Compose([
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    img = transform(img)    # (3, 256, 256)

    # encode the image
    encoder_out = encoder(img.unsqueeze(0).to(device))     # (1, enc_image_size, enc_image_size, encoder_dim)
    enc_image_size = encoder_out.size(1)
    encoder_dim = encoder_out.size(3)

    # flatten encoded image representation
    encoder_out = encoder_out.view(1, -1, encoder_dim)  # (1, num_pixels, encoder_dim)
    num_pixels = encoder_out.size(1)

    # we'll treat the problem as having a batch size of k
    encoder_out = encoder_out.expand(k, num_pixels, encoder_dim)    # (k, num_pixels, encoder_dim)

    # tensor to store top k previous words at each step; now they're just <start>
    top_k_prev_words = torch.tensor([[word_map['<start>']]] * k, dtype=torch.long).to(device)   # (k, 1)

    # tensor to store top k sequences; now they're just <start>
    top_k_seqs = top_k_prev_words   # (k, 1)

    # tensor to store top k sequences' scores; now they're just 0
    top_k_scores = torch.zeros(k, 1).to(device)     # (k, 1)

    # tensor to store top k sequences' alphas; now they're just 1s
    top_k_seqs_alpha = torch.ones(k, 1, enc_image_size, enc_image_size).to(device)  # (k, 1, enc_image_size, enc_image_size)

    # lists to store completed sequences along with their alphas and scores
    complete_seqs = []
    complete_seqs_alpha = []
    complete_seqs_scores = []

    # start decoding
    step = 1
    h, c = decoder.init_hidden_state(encoder_out)

    # s is a number less than or equal to k, because sequences are removed from this process once they hit <end>
    while True:
        embeddings = decoder.embedding(top_k_prev_words).squeeze(1)  # (s, embed_dim)

        h, c = decoder.decode_step(
            embeddings, (h, c)
        )   # (s, decoder_dim)

        scores = decoder.fc(h)      # (s, vocab_size)
        scores = F.log_softmax(scores, dim=1)

        # add the scores to prev scores
        scores = top_k_scores.expand_as(scores) + scores    # (s, vocab_size)

        # all the k points will have the same score for the first step (since same k previous words, h, c)
        if step == 1:
            top_k_scores, top_k_words = scores[0].topk(k, 0, True, True)    # (s)
        else:
            # unroll and find top scores, and their unrolled indices
            top_k_scores, top_k_words = scores.view(-1).topk(k, 0, True, True)    # (s)

        # convert unrolled indices to actual indices of scores
        prev_word_inds = top_k_words // vocab_size  # (s)
        next_word_inds = top_k_words % vocab_size  # (s)

        # add new words to sequences, alphas
        top_k_seqs = torch.cat([top_k_seqs[prev_word_inds], next_word_inds.unsqueeze(1)], dim=1)    # (s, step + 1)

        # which sequences are incomplete (didn't reach <end>)?
        incomplete_inds = [ind for ind, next_word in enumerate(next_word_inds)
                            if next_word != word_map['<end>']]
        complete_inds = list(set(range(len(next_word_inds))) - set(incomplete_inds))

        # set aside complete sequences
        if len(complete_inds) > 0:
            complete_seqs.extend(top_k_seqs[complete_inds].tolist())
            complete_seqs_scores.extend(top_k_scores[complete_inds])
        k -= len(complete_inds)  # reduce beam length accordingly

        # proceed with incomplete sequences
        if k == 0:
            break

        top_k_seqs = top_k_seqs[incomplete_inds]
        h = h[prev_word_inds[incomplete_inds]]
        c = c[prev_word_inds[incomplete_inds]]
        encoder_out = encoder_out[prev_word_inds[incomplete_inds]]
        top_k_scores = top_k_scores[incomplete_inds].unsqueeze(1)
        top_k_prev_words = next_word_inds[incomplete_inds].unsqueeze(1)

        # break if things have been going on too long
        if step > 50:
            break
        step += 1

    # select sequence with max score
    i = complete_seqs_scores.index(max(complete_seqs_scores))
    seq = complete_seqs[i]

    caption = [rev_word_map[ind] for ind in seq if rev_word_map[ind] not in ["<start>", "<end>", "<unk>", "<pad>"]]
    return ' '.join([str(word) for word in caption])

# %%
checkpoint = './drive/MyDrive/image_captioning/'+'image_captioning_best_30k_noattention.pth'
checkpoint = torch.load(checkpoint, map_location=device)
encoder = checkpoint['encoder']
decoder = checkpoint['decoder']
vocab_size = len(word2id)
result_test_dictionary={}
for idx,path in enumerate(test_image_paths):
  result_test_dictionary[idx]=[]
  caption=generate_image_caption_noattention(encoder, decoder, path, word2id)
  result_test_dictionary[idx]+=[caption]
imageId=range(len(test_image_paths))
with open("/content/drive/MyDrive/image_captioning/generated_captions.json", "w") as outfile:
    json.dump(result_test_dictionary, outfile)

# %%
print(result_test_dictionary)
